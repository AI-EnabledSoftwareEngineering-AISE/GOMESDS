# %%
import json
import pandas as pd
from tqdm import tqdm_notebook
from IPython.display import HTML, display
import tabulate
import sqlite3
from sqlite3 import Error
import random
import copy
import math


human_labels = ('woman', 'men', 'boy', 'kid', 'child', 'guy', 'man', 'person', 'girl', 'lady', 'people')

# %%
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
    except Error as e:
        print(e)

    return conn

# %%
cp_val = '/home/test_pc/mmlab/mmdetection/datasets/cp_val.json'
f = open(cp_val)
cp_val_data = json.load(f)
cp_val_cat = cp_val_data['categories']
cp_val_images = cp_val_data['images']
cp_val_annotations = cp_val_data['annotations']
cp_val_img_df = pd.DataFrame(cp_val_images)
cp_val_ann_df = pd.DataFrame(cp_val_annotations)

# %%
cp_train = '/home/test_pc/mmlab/mmdetection/datasets/cp_train.json'
f = open(cp_train)
cp_train_data = json.load(f)
# cp_train_licenses = cp_train_data['licenses']
cp_train_cat = cp_train_data['categories']
cp_train_images = cp_train_data['images']
cp_train_annotations = cp_train_data['annotations']
cp_train_img_df = pd.DataFrame(cp_train_images)
cp_train_ann_df = pd.DataFrame(cp_train_annotations)

# %%
aug_test = '/home/test_pc/mmlab/mmdetection/datasets/aug_test.json'
f = open(aug_test)
aug_test_data = json.load(f)
# aug_test_licenses = aug_test_data['licenses']
aug_test_cat = aug_test_data['categories']
aug_test_images = aug_test_data['images']
aug_test_annotations = aug_test_data['annotations']
aug_test_img_df = pd.DataFrame(aug_test_images)
aug_test_ann_df = pd.DataFrame(aug_test_annotations)

# %%
def concat_df(dataset='EuroCity'):
    ec_train = cp_train_img_df[cp_train_img_df['file_name'].str.contains(dataset)]
    ec_val = cp_val_img_df[cp_val_img_df['file_name'].str.contains(dataset)]
    ec_test = aug_test_img_df[aug_test_img_df['file_name'].str.contains(dataset)]
    ec_tr = [el.rsplit('/', 1)[1] for el in list(ec_train['file_name'])]
    ec_v = [el.rsplit('/', 1)[1] for el in list(ec_val['file_name'])]
    ec_ts = [el.rsplit('/', 1)[1] for el in list(ec_test['file_name'])]
    out_list = ec_tr + ec_v + ec_ts
    print(f'len train: {len(ec_tr)}, len val: {len(ec_v)}, len test: {len(ec_ts)}')
#     out_list.extend(ec_tr, ec_v, ec_ts)
    print(f'len all of togather is: {len(out_list)}')
    return out_list

# %%
ec_list = concat_df(dataset='EuroCity')
# Out:
# len train: 871, len val: 168, len test: 155
# len all of togather is: 1194

# %%
wp_list = concat_df(dataset='WiderPerson')
# Out:
# len train: 351, len val: 76, len test: 75
# len all of togather is: 502

# %%
ch_list = concat_df(dataset='CrowdHuman')
# Out:
# len train: 436, len val: 94, len test: 94
# len all of togather is: 624

# %%
def setA_setB(A, B):
    """
    set A - set B
    """
    common_list = []
    diff_set = []
    comm_set = []
    for idx, row in A.iterrows():
        index_list = B[(B['Object_1'] == row['Object_1'])&(B['Relation'] == row['Relation'])&(B['Object_2'] == row['Object_2'])].index.tolist()
        if not index_list:
           diff_set.append(idx) 
        else:
           comm_set.append(idx)
    diff_cp = A.iloc[diff_set]
    com_cp = A.iloc[comm_set]
    return diff_cp, com_cp

def find_quantile(diff_set,q=0.95, max_im=20):
    quantile_95 = diff_set[diff_set.Count > diff_set.Count.quantile(q)]
    quantile_95 = quantile_95.sort_values('Count', ascending=False)
    quantile_95.reset_index(drop=True, inplace=True)
    quantile_95['count_down'] = max_im
#     im_to_add = []
    for index, row in tqdm_notebook(quantile_95.iterrows(), desc ="update the r_cityperson_df"):
        if len(quantile_95.at[index, 'images']) > quantile_95.at[index, 'count_down']:
            s_images = random.sample(quantile_95.at[index, 'images'], quantile_95.at[index, 'count_down'])
            quantile_95.at[index, 'images'] = s_images
        else:
            s_images = quantile_95.at[index, 'images']
        quantile_95.at[index, 'count_down'] = quantile_95.at[index, 'count_down'] - len(s_images)
#         im_to_add.extend(s_images)

#     im_to_add = list(set(im_to_add))
#     return im_to_add, quantile_95
    return quantile_95

def splite_data(data_df, train_size=50, val_size=10, test_size=10, dt=None, examption_list=[]):
    check_list = isinstance(data_df, list)
    if check_list:
        all_images = copy.deepcopy(data_df)
    elif not dt:
        all_images = [el.rsplit('/', 1)[1] for el in data_df['file_name'].to_list()]
    else:
        all_images = data_df['file_name'].to_list()
#     data_df = copy.deepcopy(data_df)
#     all_images = list(set([item for sublist in data_df['images'].tolist() for item in sublist]))
    all_images = list(set(all_images).difference(set(examption_list)))
    
    train_images = random.sample(all_images, train_size)
    rem_images = list(set(all_images).difference(set(train_images)))
    val_images = random.sample(rem_images, val_size)
    rem_images = list(set(rem_images).difference(set(val_images)))
    test_images = random.sample(rem_images, test_size)
#     test_images = list(set(all_images).difference(set(train_images).union(set(val_images))))
    
#     print(set(train_images).intersection(set(val_images)))

#     assert len(all_images) == len(train_images) + len(val_images) + len(test_images)
    assert len(set(train_images).intersection(set(val_images))) == 0
    assert len(set(train_images).intersection(set(test_images))) == 0
    assert len(set(val_images).intersection(set(test_images))) == 0
    return train_images, val_images, test_images

def concat_df(df_list):
    bigdata = copy.deepcopy(df_list[0])
    for el in df_list[1:]:
        bigdata = bigdata.append(el, ignore_index=True)
    return bigdata

def find_index_of_images(img_df, image_name_list=None):
    index_id_list = []
    for el in image_name_list:
        index_ids = img_df.index[img_df['file_name'].str.contains(el)].tolist()
        image_id = [img_df.at[idx, 'id'] for idx in index_ids]
        if len(image_id) != 1:
            print(image_id)
        assert len(image_id) == 1
        index_id_list.append(index_ids[0])
    return index_id_list

def create_ann_df(ann_df, index_list):
    selected_ann_df = ann_df[ann_df['image_id'].isin([index_list[0] + 1])]
    for el in index_list[1:]:
        selected_ann_df = pd.concat([selected_ann_df,ann_df[ann_df['image_id'].isin([el + 1])]])
    return selected_ann_df

def create_img_df(img_df, index_list):
    selected_img_df = img_df.loc[[index_list[0]]]
    for el in index_list[1:]:
        selected_img_df = pd.concat([selected_img_df,img_df.loc[[el]]])
    return selected_img_df

def update_img_ids(aug_img_df, row=None, dataset='other'):
    last_id = aug_img_df.at[aug_img_df.index[-1], 'id']
    concat_df = pd.concat([aug_img_df, row])
    concat_df.reset_index(drop=True, inplace=True)
    concat_df.at[concat_df.index[-1], 'id'] = last_id + 1
#     if dataset == 'ch':
#         concat_df.at[concat_df.index[-1], 'file_name'] = 'CrowdHuman/Images/' + concat_df.at[concat_df.index[-1], 'file_name']
    return last_id + 1, concat_df

def uodate_id_in_image_ann(selected_img_df, aug_img_df, selected_ann_df, dt='other'):
    selected_img_df = selected_img_df.sort_values('id')
    if dt == 'ch':
        selected_ann_df['height'] = ""
        selected_ann_df['width'] = ""
        for idx, row in selected_img_df.iterrows():
            new_image_id, aug_img_df = update_img_ids(aug_img_df, row=selected_img_df.loc[[idx]], dataset='ch')
            
            selected_ann_df.loc[selected_ann_df['image_id'] == idx + 1, 'height'] = aug_img_df.at[new_image_id -1, 'height']
            selected_ann_df.loc[selected_ann_df['image_id'] == idx + 1, 'width'] = aug_img_df.at[new_image_id -1, 'width']
            
            selected_ann_df.loc[selected_ann_df['image_id'] == idx + 1, 'image_id'] = new_image_id

    else:
        for idx, row in selected_img_df.iterrows():
            new_image_id, aug_img_df = update_img_ids(aug_img_df, row=selected_img_df.loc[[idx]])
            if 'image_id' in selected_ann_df.columns:
                selected_ann_df.loc[selected_ann_df['image_id'] == idx + 1, 'image_id'] = new_image_id
    
    return aug_img_df, selected_ann_df

def concat_ann_df(orig_df, add_df):
    ann_df_c = pd.concat([orig_df, add_df])
    ann_df_c.reset_index(drop=True, inplace=True)
    for idx, row in ann_df_c.iterrows():
        if idx + 1 != row['id']:
            ann_df_c.at[idx, 'id'] = idx + 1
    return ann_df_c

# %%
def add_area(df):
    df = copy.deepcopy(df)
    df['area'] = ""
    for idx, row in df.iterrows():
        bb = df.loc[df['id'] == idx + 1, 'bbox']
        bb = bb.tolist()[0]
        df.loc[df['id'] == idx + 1, 'area'] = bb[2]*bb[3]
    return df

# %% [markdown]
# # create annotatuion file
# #### selected data frames :

# %%
cp_file = '/home/test_pc/mmlab/mmdetection/datasets/cityperson_train.json'
f = open(cp_file)
cp_data = json.load(f)
# cp_licenses = cp_data['licenses']
cp_categories = cp_data['categories']
cp_images = cp_data['images']
cp_annotations = cp_data['annotations']
cp_img_df = pd.DataFrame(cp_images)
cp_ann_df = pd.DataFrame(cp_annotations)

# %%
print(cp_data['categories'])
# Out:
# [{'id': 1, 'name': 'pedestrain', 'supercategory': 'pedestrain'}]

# %%
# for idx, row in cp_img_df.iterrows():
#     cp_img_df.at[cp_img_df.index[idx], 'file_name'] = 'CityPersons/' + cp_img_df.at[cp_img_df.index[idx], 'file_name']
aug_img_df = copy.deepcopy(cp_img_df)
aug_img_df
# Out:
#         id                                          file_name  width  height  \
# 0        1  CityPersons/leftImg8bit_trainvaltest//leftImg8...   2048    1024
# 1        2  CityPersons/leftImg8bit_trainvaltest//leftImg8...   2048    1024
# 2        3  CityPersons/leftImg8bit_trainvaltest//leftImg8...   2048    1024
# 3        4  CityPersons/leftImg8bit_trainvaltest//leftImg8...   2048    1024
# 4        5  CityPersons/leftImg8bit_trainvaltest//leftImg8...   2048    1024
# ...    ...                                                ...    ...     ...
# 2524  2525  CityPersons/leftImg8bit_trainvaltest//leftImg8...   2048    1024
# 2525  2526  CityPersons/leftImg8bit_trainvaltest//leftImg8...   2048    1024
# 2526  2527  CityPersons/leftImg8bit_trainvaltest//leftImg8...   2048    1024
# 2527  2528  CityPersons/leftImg8bit_trainvaltest//leftImg8...   2048    1024
# 2528  2529  CityPersons/leftImg8bit_trainvaltest//leftImg8...   2048    1024
#
#                    date_captured  license coco_url flickr_url
# 0     2019-07-25 11:20:43.195846        1
# 1     2019-07-25 11:20:43.195846        1
# 2     2019-07-25 11:20:43.195846        1
# 3     2019-07-25 11:20:43.195846        1
# 4     2019-07-25 11:20:43.195846        1
# ...                          ...      ...      ...        ...
# 2524  2019-07-25 11:20:43.195846        1
# 2525  2019-07-25 11:20:43.195846        1
# 2526  2019-07-25 11:20:43.195846        1
# 2527  2019-07-25 11:20:43.195846        1
# 2528  2019-07-25 11:20:43.195846        1
#
# [2529 rows x 8 columns]

# %%
# cp_ann_df = add_area(cp_ann_df)
cp_ann_df
# Out:
#           id  image_id  category_id  iscrowd                         bbox  \
# 0          1         1            1     True  [1034.0, 366.0, 31.0, 75.0]
# 1          2         1            1     True  [1911.0, 359.0, 10.0, 54.0]
# 2          3         1            1     True    [1137.0, 307.0, 8.0, 9.0]
# 3          4         2            1    False  [602.0, 413.0, 60.0, 146.0]
# 4          5         2            1    False  [281.0, 381.0, 89.0, 216.0]
# ...      ...       ...          ...      ...                          ...
# 23424  23425      2529            1     True  [1570.0, 376.0, 20.0, 48.0]
# 23425  23426      2529            1     True   [416.0, 300.0, 15.0, 58.0]
# 23426  23427      2529            1     True  [1679.0, 361.0, 27.0, 59.0]
# 23427  23428      2529            1    False  [1662.0, 366.0, 26.0, 63.0]
# 23428  23429      2529            1     True  [1558.0, 380.0, 18.0, 43.0]
#
#        width  height     area
# 0       2048    1024   2325.0
# 1       2048    1024    540.0
# 2       2048    1024     72.0
# 3       2048    1024   8760.0
# 4       2048    1024  19224.0
# ...      ...     ...      ...
# 23424   2048    1024    960.0
# 23425   2048    1024    870.0
# 23426   2048    1024   1593.0
# 23427   2048    1024   1638.0
# 23428   2048    1024    774.0
#
# [23429 rows x 8 columns]

# %%
cp_info = copy.deepcopy(cp_data['info'])
cp_cat = copy.deepcopy(cp_data['categories'])
cp_data['categories']
# Out:
# [{'id': 1, 'name': 'pedestrain', 'supercategory': 'pedestrain'}]

# %%
# aug_data_train['info'] = cp_info
# aug_data_train['categories'] = cp_cat
# aug_data_train['images'] = aug_img_df.to_dict('records')
# aug_data_train['annotations'] = cp_ann_df.to_dict('records')
# with open('/home/test_pc/mmlab/mmdetection/datasets/cityperson_train.json', 'w') as fp:
#     json.dump(aug_data_train, fp)

# %% [markdown]
# ## ECP

# %%
ecp_file = 'json_files/EuroCity/day_train_all.json'
f = open(ecp_file)
ecp_data = json.load(f)
ecp_licenses = ecp_data['licenses']
ecp_categories = ecp_data['categories']
ecp_images = ecp_data['images']
ecp_annotations = ecp_data['annotations']
ecp_img_df = pd.DataFrame(ecp_images)
ecp_ann_df = pd.DataFrame(ecp_annotations)
ecp_img_df.shape[0]
# Out:
# 23892

# %%
print(ecp_data['categories'])
# Out:
# [{'id': 1, 'name': 'pedestrain', 'supercategory': 'pedestrain'}]

# %%
for idx, row in ecp_img_df.iterrows():
    ecp_img_df.at[ecp_img_df.index[idx], 'file_name'] = 'EuroCity/' + ecp_img_df.at[ecp_img_df.index[idx], 'file_name']
ecp_img_df
# Out:
#           id                                          file_name  width  \
# 0          1  EuroCity/ECP/day/img/train/wuerzburg/wuerzburg...   1920
# 1          2  EuroCity/ECP/day/img/train/wuerzburg/wuerzburg...   1920
# 2          3  EuroCity/ECP/day/img/train/wuerzburg/wuerzburg...   1920
# 3          4  EuroCity/ECP/day/img/train/wuerzburg/wuerzburg...   1920
# 4          5  EuroCity/ECP/day/img/train/wuerzburg/wuerzburg...   1920
# ...      ...                                                ...    ...
# 23887  23888  EuroCity/ECP/day/img/train/potsdam/potsdam_004...   1920
# 23888  23889  EuroCity/ECP/day/img/train/potsdam/potsdam_000...   1920
# 23889  23890  EuroCity/ECP/day/img/train/potsdam/potsdam_005...   1920
# 23890  23891  EuroCity/ECP/day/img/train/potsdam/potsdam_003...   1920
# 23891  23892  EuroCity/ECP/day/img/train/potsdam/potsdam_000...   1920
#
#        height               date_captured  license coco_url flickr_url
# 0        1024  2019-11-03 07:44:18.143034        1
# 1        1024  2019-11-03 07:44:18.143034        1
# 2        1024  2019-11-03 07:44:18.143034        1
# 3        1024  2019-11-03 07:44:18.143034        1
# 4        1024  2019-11-03 07:44:18.143034        1
# ...       ...                         ...      ...      ...        ...
# 23887    1024  2019-11-03 07:44:18.143034        1
# 23888    1024  2019-11-03 07:44:18.143034        1
# 23889    1024  2019-11-03 07:44:18.143034        1
# 23890    1024  2019-11-03 07:44:18.143034        1
# 23891    1024  2019-11-03 07:44:18.143034        1
#
# [23892 rows x 8 columns]

# %%
train_img_ecp, val_img_ecp, test_ecp_img = splite_data(ecp_img_df, train_size=871, val_size=168, test_size=155, examption_list=ec_list)
# train_img_ecp

# %%
train_img_ecp
# Out:
# ['budapest_00163.png',
#  'barcelona_00775.png',
#  'marseille_01047.png',
#  'berlin_00002.png',
#  'barcelona_00707.png',
#  'barcelona_00620.png',
#  'brno_00954.png',
#  'amsterdam_00596.png',
#  'pisa_00040.png',
#  'ulm_00191.png',
#  'roma_00718.png',
#  'toulouse_00323.png',
#  'pisa_00085.png',
#  'bratislava_00750.png',
#  'ulm_00239.png',
#  'nuernberg_00012.png',
#  'ulm_00607.png',
#  'torino_00711.png',
#  'bologna_00575.png',
#  'montpellier_00256.png',
#  'barcelona_00239.png',
#  'prague_01081.png',
#  'hamburg_00049.png',
#  'montpellier_00041.png',
#  'ljubljana_00837.png',
#  'marseille_01183.png',
#  'milano_00827.png',
#  'barcelona_00585.png',
#  'amsterdam_00158.png',
#  'zagreb_00128.png',
#  'marseille_00319.png',
#  'toulouse_00618.png',
#  'potsdam_00197.png',
#  'marseille_01297.png',
#  'bologna_00086.png',
#  'amsterdam_00100.png',
#  'amsterdam_00138.png',
#  'torino_00490.png',
#  'firenze_00566.png',
#  'brno_00287.png',
#  'firenze_00389.png',
#  'milano_00574.png',
#  'budapest_00454.png',
#  'bologna_00425.png',
#  'potsdam_00466.png',
#  'prague_00216.png',
#  'nuernberg_00545.png',
#  'wuerzburg_00330.png',
#  'ljubljana_00552.png',
#  'marseille_01243.png',
#  'ljubljana_00500.png',
#  'torino_00565.png',
#  'zagreb_00432.png',
#  'bologna_01221.png',
#  'brno_00802.png',
#  'bologna_00352.png',
#  'nuernberg_00308.png',
#  'montpellier_00622.png',
#  'barcelona_00714.png',
#  'toulouse_00672.png',
#  'berlin_00212.png',
#  'ljubljana_00831.png',
#  'amsterdam_00136.png',
#  'firenze_00583.png',
#  'bratislava_00197.png',
#  'potsdam_00164.png',
#  'stuttgart_00491.png',
#  'stuttgart_00397.png',
#  'marseille_00952.png',
#  'brno_00353.png',
#  'prague_00281.png',
#  'szczecin_00040.png',
#  'bratislava_00237.png',
#  'amsterdam_01009.png',
#  'marseille_00046.png',
#  'hamburg_00423.png',
#  'nuernberg_00267.png',
#  'roma_00379.png',
#  'ljubljana_00720.png',
#  'bologna_00323.png',
#  'marseille_01023.png',
#  'marseille_00558.png',
#  'marseille_00276.png',
#  'barcelona_01066.png',
#  'szczecin_00004.png',
#  'nuernberg_00127.png',
#  'marseille_00590.png',
#  'roma_01089.png',
#  'brno_00477.png',
#  'nuernberg_00242.png',
#  'milano_00676.png',
#  'roma_01081.png',
#  'bologna_00266.png',
#  'roma_00659.png',
#  'firenze_00519.png',
#  'bratislava_00234.png',
#  'amsterdam_00532.png',
#  'koeln_00121.png',
#  'ulm_00576.png',
#  'dresden_00287.png',
#  'zagreb_00107.png',
#  'amsterdam_00798.png',
#  'montpellier_00390.png',
#  'torino_00912.png',
#  'szczecin_00160.png',
#  'torino_00176.png',
#  'leipzig_00174.png',
#  'marseille_01292.png',
#  'roma_00475.png',
#  'brno_00201.png',
#  'ulm_00184.png',
#  'zagreb_00298.png',
#  'bratislava_00282.png',
#  'roma_00684.png',
#  'dresden_00329.png',
#  'roma_00263.png',
#  'basel_00517.png',
#  'firenze_01128.png',
#  'torino_00303.png',
#  'ljubljana_00611.png',
#  'firenze_00710.png',
#  'firenze_00224.png',
#  'ulm_00342.png',
#  'basel_00373.png',
#  'barcelona_00243.png',
#  'montpellier_00490.png',
#  'budapest_00054.png',
#  'torino_00736.png',
#  'bratislava_00479.png',
#  'dresden_00575.png',
#  'bologna_00980.png',
#  'marseille_00051.png',
#  'ulm_00294.png',
#  'basel_00097.png',
#  'toulouse_00538.png',
#  'roma_00255.png',
#  'milano_00630.png',
#  'prague_01134.png',
#  'torino_00872.png',
#  'zuerich_00065.png',
#  'dresden_00662.png',
#  'toulouse_00427.png',
#  'berlin_00195.png',
#  'potsdam_00235.png',
#  'milano_00741.png',
#  'amsterdam_00269.png',
#  'berlin_00208.png',
#  'leipzig_00408.png',
#  'marseille_00940.png',
#  'hamburg_00422.png',
#  'milano_00371.png',
#  'ulm_00178.png',
#  'bratislava_00078.png',
#  'roma_00077.png',
#  'bratislava_00617.png',
#  'brno_00613.png',
#  'barcelona_00687.png',
#  'wuerzburg_00127.png',
#  'bratislava_00023.png',
#  'torino_00666.png',
#  'stuttgart_00061.png',
#  'brno_00126.png',
#  'firenze_00301.png',
#  'leipzig_00118.png',
#  'marseille_01118.png',
#  'hamburg_00630.png',
#  'ljubljana_00874.png',
#  'milano_00305.png',
#  'bratislava_00261.png',
#  'stuttgart_00437.png',
#  'amsterdam_00663.png',
#  'montpellier_00324.png',
#  'berlin_00043.png',
#  'roma_00415.png',
#  'pisa_00169.png',
#  'marseille_00544.png',
#  'barcelona_00877.png',
#  'bratislava_00458.png',
#  'firenze_00061.png',
#  'marseille_00955.png',
#  'nuernberg_00117.png',
#  'amsterdam_01033.png',
#  'prague_00557.png',
#  'ljubljana_00248.png',
#  'marseille_00528.png',
#  'dresden_00174.png',
#  'zuerich_00243.png',
#  'roma_00444.png',
#  'szczecin_00018.png',
#  'amsterdam_00951.png',
#  'nuernberg_00723.png',
#  'bratislava_00817.png',
#  'amsterdam_00509.png',
#  'zagreb_00111.png',
#  'prague_01016.png',
#  'milano_00664.png',
#  'dresden_00214.png',
#  'milano_00002.png',
#  'wuerzburg_00134.png',
#  'prague_00681.png',
#  'barcelona_00574.png',
#  'firenze_00915.png',
#  'budapest_00421.png',
#  'barcelona_00536.png',
#  'roma_01007.png',
#  'milano_00079.png',
#  'montpellier_00473.png',
#  'bologna_00449.png',
#  'ulm_00590.png',
#  'amsterdam_00492.png',
#  'koeln_00011.png',
#  'torino_00097.png',
#  'ljubljana_00773.png',
#  'budapest_00642.png',
#  'ljubljana_00246.png',
#  'milano_00789.png',
#  'koeln_00036.png',
#  'marseille_00834.png',
#  'nuernberg_00679.png',
#  'milano_00860.png',
#  'hamburg_00672.png',
#  'montpellier_00443.png',
#  'basel_00422.png',
#  'roma_01025.png',
#  'hamburg_00401.png',
#  'barcelona_00450.png',
#  'marseille_00219.png',
#  'bologna_00600.png',
#  'marseille_00376.png',
#  'roma_00597.png',
#  'koeln_00113.png',
#  'bologna_00983.png',
#  'firenze_00907.png',
#  'bratislava_00628.png',
#  'brno_00597.png',
#  'prague_01192.png',
#  'montpellier_00233.png',
#  'wuerzburg_00569.png',
#  'barcelona_00129.png',
#  'budapest_00102.png',
#  'wuerzburg_00551.png',
#  'stuttgart_00534.png',
#  'roma_00769.png',
#  'budapest_00193.png',
#  'ulm_00588.png',
#  'nuernberg_00059.png',
#  'dresden_00224.png',
#  'brno_00415.png',
#  'brno_00103.png',
#  'koeln_00118.png',
#  'hamburg_00421.png',
#  'bratislava_00066.png',
#  'prague_00437.png',
#  'bologna_00683.png',
#  'bologna_01032.png',
#  'amsterdam_00981.png',
#  'wuerzburg_00335.png',
#  'ljubljana_00371.png',
#  'marseille_01059.png',
#  'budapest_00075.png',
#  'firenze_00076.png',
#  'dresden_00544.png',
#  'ljubljana_00243.png',
#  'amsterdam_00127.png',
#  'montpellier_00592.png',
#  'montpellier_00179.png',
#  'barcelona_00297.png',
#  'bologna_00837.png',
#  'prague_01122.png',
#  'prague_00291.png',
#  'budapest_00700.png',
#  'basel_00288.png',
#  'leipzig_00045.png',
#  'nuernberg_00655.png',
#  'prague_01119.png',
#  'marseille_00044.png',
#  'dresden_00358.png',
#  'basel_00212.png',
#  'roma_00894.png',
#  'barcelona_00277.png',
#  'pisa_00133.png',
#  'marseille_01201.png',
#  'wuerzburg_00326.png',
#  'roma_00358.png',
#  'ulm_00196.png',
#  'budapest_00680.png',
#  'potsdam_00148.png',
#  'bologna_00089.png',
#  'firenze_00909.png',
#  'torino_00657.png',
#  'budapest_00784.png',
#  'nuernberg_00710.png',
#  'barcelona_01074.png',
#  'budapest_00147.png',
#  'ljubljana_00725.png',
#  'zuerich_00285.png',
#  'brno_00225.png',
#  'dresden_00736.png',
#  'koeln_00026.png',
#  'roma_00277.png',
#  'bratislava_00444.png',
#  'barcelona_00049.png',
#  'brno_00627.png',
#  'prague_01290.png',
#  'zagreb_00085.png',
#  'prague_00657.png',
#  'marseille_01085.png',
#  'milano_00021.png',
#  'marseille_00152.png',
#  'prague_01259.png',
#  'basel_00035.png',
#  'zagreb_00386.png',
#  'ulm_00459.png',
#  'hamburg_00019.png',
#  'firenze_00546.png',
#  'potsdam_00056.png',
#  'bologna_00732.png',
#  'hamburg_00348.png',
#  'basel_00005.png',
#  'torino_00353.png',
#  'roma_00843.png',
#  'marseille_00552.png',
#  'marseille_00445.png',
#  'nuernberg_00109.png',
#  'wuerzburg_00271.png',
#  'potsdam_00475.png',
#  'toulouse_00039.png',
#  'toulouse_00090.png',
#  'marseille_01221.png',
#  'firenze_01022.png',
#  'hamburg_00427.png',
#  'hamburg_00299.png',
#  'dresden_00057.png',
#  'barcelona_00905.png',
#  'montpellier_00553.png',
#  'ljubljana_00865.png',
#  'amsterdam_00805.png',
#  'pisa_00546.png',
#  'torino_00649.png',
#  'milano_00683.png',
#  'pisa_00130.png',
#  'torino_00573.png',
#  'barcelona_00869.png',
#  'amsterdam_00695.png',
#  'ulm_00174.png',
#  'leipzig_00331.png',
#  'potsdam_00439.png',
#  'marseille_01097.png',
#  'prague_00914.png',
#  'nuernberg_00614.png',
#  'bologna_00611.png',
#  'prague_00550.png',
#  'marseille_00236.png',
#  'basel_00456.png',
#  'zuerich_00355.png',
#  'barcelona_00486.png',
#  'leipzig_00228.png',
#  'szczecin_00259.png',
#  'hamburg_00123.png',
#  'firenze_00538.png',
#  'roma_00417.png',
#  'firenze_00110.png',
#  'firenze_00490.png',
#  'montpellier_00566.png',
#  'budapest_00019.png',
#  'roma_00034.png',
#  'leipzig_00306.png',
#  'marseille_01043.png',
#  'firenze_00867.png',
#  'basel_00625.png',
#  'barcelona_00455.png',
#  'montpellier_00180.png',
#  'barcelona_01239.png',
#  'potsdam_00480.png',
#  'prague_00468.png',
#  'bologna_00648.png',
#  'bologna_01063.png',
#  'milano_00255.png',
#  'wuerzburg_00197.png',
#  'bratislava_00402.png',
#  'marseille_00518.png',
#  'bologna_00534.png',
#  'szczecin_00027.png',
#  'dresden_00574.png',
#  'barcelona_00613.png',
#  'barcelona_00566.png',
#  'prague_00003.png',
#  'milano_00601.png',
#  'bologna_01018.png',
#  'bologna_00368.png',
#  'stuttgart_00345.png',
#  'roma_00602.png',
#  'barcelona_00890.png',
#  'nuernberg_00226.png',
#  'toulouse_00458.png',
#  'brno_00514.png',
#  'prague_00268.png',
#  'amsterdam_00328.png',
#  'firenze_00810.png',
#  'potsdam_00451.png',
#  'prague_01295.png',
#  'zagreb_00420.png',
#  'potsdam_00158.png',
#  'roma_00844.png',
#  'nuernberg_00020.png',
#  'dresden_00364.png',
#  'bratislava_00089.png',
#  'roma_00155.png',
#  'bologna_00393.png',
#  'dresden_00487.png',
#  'prague_01111.png',
#  'prague_01008.png',
#  'montpellier_00431.png',
#  'montpellier_00357.png',
#  'toulouse_00375.png',
#  'roma_00882.png',
#  'wuerzburg_00565.png',
#  'firenze_00454.png',
#  'budapest_00155.png',
#  'hamburg_00100.png',
#  'roma_01093.png',
#  'ljubljana_00362.png',
#  'dresden_00620.png',
#  'prague_01240.png',
#  'zagreb_00381.png',
#  'potsdam_00138.png',
#  'zuerich_00365.png',
#  'pisa_00218.png',
#  'barcelona_01030.png',
#  'amsterdam_00358.png',
#  'pisa_00138.png',
#  'budapest_00067.png',
#  'zagreb_00632.png',
#  'dresden_00204.png',
#  'marseille_00490.png',
#  'milano_00511.png',
#  'nuernberg_00508.png',
#  'milano_00668.png',
#  'roma_00001.png',
#  'roma_00532.png',
#  'roma_00087.png',
#  'amsterdam_00685.png',
#  'roma_01063.png',
#  'torino_00559.png',
#  'bratislava_00115.png',
#  'torino_00477.png',
#  'roma_00895.png',
#  'amsterdam_00468.png',
#  'ljubljana_00842.png',
#  'torino_00739.png',
#  'dresden_00357.png',
#  'toulouse_00420.png',
#  'hamburg_00252.png',
#  'prague_00209.png',
#  'prague_00533.png',
#  'pisa_00084.png',
#  'ljubljana_00644.png',
#  'montpellier_00100.png',
#  'barcelona_01236.png',
#  'berlin_00088.png',
#  'zagreb_00168.png',
#  'bologna_00367.png',
#  'torino_00159.png',
#  'prague_00272.png',
#  'wuerzburg_00248.png',
#  'roma_00834.png',
#  'pisa_00558.png',
#  'nuernberg_00528.png',
#  'barcelona_01073.png',
#  'firenze_00540.png',
#  'toulouse_00516.png',
#  'firenze_00028.png',
#  'lyon_00027.png',
#  'berlin_00071.png',
#  'marseille_00738.png',
#  'bratislava_00161.png',
#  'milano_00120.png',
#  'zagreb_00419.png',
#  'bologna_00801.png',
#  'toulouse_00210.png',
#  'brno_00086.png',
#  'stuttgart_00220.png',
#  'ljubljana_00429.png',
#  'pisa_00327.png',
#  'ljubljana_00004.png',
#  'barcelona_00066.png',
#  'nuernberg_00386.png',
#  'wuerzburg_00033.png',
#  'hamburg_00087.png',
#  'hamburg_00414.png',
#  'marseille_00853.png',
#  'roma_00066.png',
#  'bologna_01006.png',
#  'basel_00048.png',
#  'wuerzburg_00123.png',
#  'nuernberg_00006.png',
#  'berlin_00075.png',
#  'hamburg_00153.png',
#  'milano_00133.png',
#  'wuerzburg_00234.png',
#  'ulm_00113.png',
#  'prague_00407.png',
#  'bologna_00110.png',
#  'montpellier_00087.png',
#  'torino_00204.png',
#  'lyon_00121.png',
#  'brno_00057.png',
#  'toulouse_00187.png',
#  'ljubljana_00745.png',
#  'torino_00186.png',
#  'bologna_00843.png',
#  'torino_00730.png',
#  'dresden_00527.png',
#  'budapest_00699.png',
#  'amsterdam_00214.png',
#  'nuernberg_00492.png',
#  'barcelona_01238.png',
#  'ljubljana_00099.png',
#  'bratislava_00048.png',
#  'firenze_00952.png',
#  'potsdam_00027.png',
#  'toulouse_00428.png',
#  'firenze_00154.png',
#  'bologna_00953.png',
#  'prague_00630.png',
#  'amsterdam_00183.png',
#  'barcelona_00598.png',
#  'amsterdam_00193.png',
#  'prague_01341.png',
#  'stuttgart_00521.png',
#  'szczecin_00187.png',
#  'leipzig_00067.png',
#  'toulouse_00033.png',
#  'ljubljana_00213.png',
#  'koeln_00183.png',
#  'brno_00832.png',
#  'szczecin_00181.png',
#  'prague_00560.png',
#  'nuernberg_00080.png',
#  'brno_00743.png',
#  'brno_00179.png',
#  'basel_00222.png',
#  'prague_00665.png',
#  'amsterdam_00630.png',
#  'basel_00134.png',
#  'zagreb_00502.png',
#  'barcelona_00112.png',
#  'firenze_01143.png',
#  'basel_00103.png',
#  'prague_01172.png',
#  'torino_00696.png',
#  'koeln_00047.png',
#  'potsdam_00130.png',
#  'ljubljana_00600.png',
#  'zagreb_00187.png',
#  'hamburg_00198.png',
#  'leipzig_00069.png',
#  'basel_00128.png',
#  'basel_00106.png',
#  'amsterdam_00284.png',
#  'roma_00934.png',
#  'dresden_00136.png',
#  'barcelona_00122.png',
#  'dresden_00316.png',
#  'torino_00713.png',
#  'milano_00344.png',
#  'firenze_00194.png',
#  'torino_00410.png',
#  'firenze_00722.png',
#  'wuerzburg_00449.png',
#  'milano_00374.png',
#  'torino_00401.png',
#  'stuttgart_00024.png',
#  'roma_00760.png',
#  'dresden_00103.png',
#  'barcelona_01049.png',
#  'szczecin_00374.png',
#  'toulouse_00089.png',
#  'firenze_00025.png',
#  'marseille_00976.png',
#  'bologna_00642.png',
#  'marseille_00634.png',
#  'barcelona_01203.png',
#  'milano_00350.png',
#  'nuernberg_00549.png',
#  'stuttgart_00157.png',
#  'brno_00543.png',
#  'dresden_00514.png',
#  'koeln_00044.png',
#  'marseille_00549.png',
#  'roma_00124.png',
#  'amsterdam_00879.png',
#  'brno_00878.png',
#  'brno_00655.png',
#  'dresden_00628.png',
#  'wuerzburg_00132.png',
#  'torino_00683.png',
#  'zagreb_00544.png',
#  'barcelona_00395.png',
#  'dresden_00548.png',
#  'barcelona_00303.png',
#  'nuernberg_00282.png',
#  'marseille_01150.png',
#  'barcelona_00726.png',
#  'brno_00702.png',
#  'milano_00750.png',
#  'leipzig_00428.png',
#  'prague_00411.png',
#  'budapest_00038.png',
#  'lyon_00107.png',
#  'marseille_00066.png',
#  'montpellier_00288.png',
#  'torino_00817.png',
#  'marseille_00618.png',
#  'wuerzburg_00347.png',
#  'ljubljana_00202.png',
#  'bratislava_00622.png',
#  'toulouse_00507.png',
#  'marseille_00416.png',
#  'dresden_00657.png',
#  'marseille_00101.png',
#  'roma_00802.png',
#  'montpellier_00393.png',
#  'leipzig_00145.png',
#  'potsdam_00031.png',
#  'potsdam_00029.png',
#  'bologna_00212.png',
#  'firenze_00745.png',
#  'zagreb_00129.png',
#  'dresden_00245.png',
#  'basel_00627.png',
#  'hamburg_00375.png',
#  'bologna_00733.png',
#  'montpellier_00310.png',
#  'roma_00339.png',
#  'hamburg_00154.png',
#  'ljubljana_00312.png',
#  'brno_00915.png',
#  'prague_00674.png',
#  'marseille_00215.png',
#  'nuernberg_00298.png',
#  'firenze_00866.png',
#  'roma_01032.png',
#  'prague_00881.png',
#  'prague_00152.png',
#  'leipzig_00238.png',
#  'ljubljana_00158.png',
#  'ulm_00322.png',
#  'firenze_00143.png',
#  'barcelona_00321.png',
#  'brno_00476.png',
#  'ljubljana_00632.png',
#  'hamburg_00668.png',
#  'potsdam_00206.png',
#  'amsterdam_00472.png',
#  'zuerich_00193.png',
#  'roma_00620.png',
#  'prague_00116.png',
#  'wuerzburg_00016.png',
#  'bologna_00313.png',
#  'stuttgart_00273.png',
#  'dresden_00656.png',
#  'basel_00061.png',
#  'bologna_01185.png',
#  'wuerzburg_00139.png',
#  'hamburg_00340.png',
#  'barcelona_00177.png',
#  'firenze_00218.png',
#  'stuttgart_00275.png',
#  'zagreb_00473.png',
#  'firenze_00452.png',
#  'bologna_00908.png',
#  'budapest_00266.png',
#  'toulouse_00520.png',
#  'prague_00264.png',
#  'bratislava_00710.png',
#  'budapest_00156.png',
#  'wuerzburg_00292.png',
#  'brno_00176.png',
#  'prague_00697.png',
#  'zagreb_00505.png',
#  'prague_00483.png',
#  'amsterdam_00634.png',
#  'bologna_00877.png',
#  'stuttgart_00545.png',
#  'marseille_01169.png',
#  'ljubljana_00625.png',
#  'marseille_00675.png',
#  'montpellier_00224.png',
#  'lyon_00017.png',
#  'bratislava_00045.png',
#  'hamburg_00523.png',
#  'potsdam_00103.png',
#  'brno_00257.png',
#  'wuerzburg_00577.png',
#  'hamburg_00357.png',
#  'roma_00971.png',
#  'barcelona_00083.png',
#  'koeln_00000.png',
#  'bratislava_00521.png',
#  'szczecin_00232.png',
#  'barcelona_00770.png',
#  'bologna_01168.png',
#  'milano_00802.png',
#  'pisa_00520.png',
#  'bratislava_00189.png',
#  'basel_00052.png',
#  'dresden_00516.png',
#  'stuttgart_00416.png',
#  'marseille_00997.png',
#  'szczecin_00301.png',
#  'montpellier_00103.png',
#  'marseille_00730.png',
#  'budapest_00696.png',
#  'budapest_00688.png',
#  'ulm_00580.png',
#  'montpellier_00504.png',
#  'potsdam_00252.png',
#  'berlin_00306.png',
#  'bologna_01122.png',
#  'firenze_01052.png',
#  'torino_00279.png',
#  'ulm_00134.png',
#  'pisa_00568.png',
#  'torino_00066.png',
#  'roma_00259.png',
#  'prague_01159.png',
#  'firenze_00196.png',
#  'roma_00798.png',
#  'ljubljana_00742.png',
#  'bratislava_00483.png',
#  'firenze_01051.png',
#  'prague_00091.png',
#  'torino_00926.png',
#  'roma_00965.png',
#  'hamburg_00535.png',
#  'leipzig_00305.png',
#  'bologna_00764.png',
#  'torino_00143.png',
#  'zagreb_00491.png',
#  'milano_00488.png',
#  'prague_00957.png',
#  'marseille_01093.png',
#  'hamburg_00129.png',
#  'toulouse_00037.png',
#  'firenze_00471.png',
#  'roma_00390.png',
#  'marseille_00187.png',
#  'barcelona_00308.png',
#  'potsdam_00244.png',
#  'potsdam_00075.png',
#  'ulm_00314.png',
#  'brno_00244.png',
#  'bologna_00159.png',
#  'stuttgart_00399.png',
#  'dresden_00107.png',
#  'ljubljana_00630.png',
#  'barcelona_00431.png',
#  'stuttgart_00069.png',
#  'firenze_00248.png',
#  'wuerzburg_00344.png',
#  'bologna_00989.png',
#  'firenze_00222.png',
#  'dresden_00594.png',
#  'amsterdam_00590.png',
#  'amsterdam_00302.png',
#  'basel_00382.png',
#  'brno_00455.png',
#  'budapest_00288.png',
#  'firenze_00219.png',
#  'zagreb_00573.png',
#  'roma_00471.png',
#  'marseille_00460.png',
#  'nuernberg_00494.png',
#  'basel_00094.png',
#  'marseille_00768.png',
#  'pisa_00187.png',
#  'nuernberg_00513.png',
#  'stuttgart_00046.png',
#  'firenze_00558.png',
#  'milano_00237.png',
#  'toulouse_00195.png',
#  'bratislava_00205.png',
#  'roma_00310.png',
#  'roma_00811.png',
#  'ulm_00350.png',
#  'barcelona_01075.png',
#  'stuttgart_00465.png',
#  'nuernberg_00339.png',
#  'barcelona_01037.png',
#  'prague_00137.png',
#  'ulm_00280.png',
#  'leipzig_00263.png',
#  'budapest_00149.png',
#  'firenze_00340.png',
#  'budapest_00361.png',
#  'bologna_00970.png',
#  'berlin_00331.png',
#  'bologna_00334.png',
#  'brno_00758.png',
#  'milano_00739.png',
#  'dresden_00104.png',
#  'budapest_00212.png',
#  'zuerich_00054.png',
#  'marseille_00278.png',
#  'firenze_00096.png',
#  'bratislava_00730.png',
#  'amsterdam_00272.png',
#  'budapest_00239.png',
#  'amsterdam_00615.png',
#  'brno_00603.png',
#  'marseille_00663.png',
#  'brno_00704.png',
#  'montpellier_00432.png',
#  'zagreb_00204.png',
#  'dresden_00284.png',
#  'berlin_00374.png',
#  'barcelona_00725.png',
#  'zagreb_00338.png',
#  'szczecin_00174.png',
#  'potsdam_00182.png',
#  'barcelona_01126.png',
#  'ulm_00291.png',
#  'nuernberg_00726.png',
#  'nuernberg_00347.png',
#  'pisa_00407.png',
#  'nuernberg_00505.png',
#  'berlin_00204.png',
#  'lyon_00038.png',
#  'budapest_00175.png',
#  'prague_00498.png',
#  'ljubljana_00541.png',
#  'marseille_00992.png',
#  'marseille_00499.png',
#  'montpellier_00327.png',
#  'stuttgart_00267.png',
#  'torino_00089.png',
#  'pisa_00477.png',
#  'bologna_01074.png',
#  'ljubljana_00276.png',
#  'barcelona_00463.png',
#  'prague_00030.png',
#  'torino_00956.png',
#  'zagreb_00597.png',
#  'ljubljana_00862.png',
#  'torino_00690.png',
#  'firenze_01112.png',
#  'budapest_00768.png',
#  'leipzig_00068.png',
#  'bologna_00921.png',
#  'montpellier_00378.png',
#  'milano_00659.png',
#  'roma_00996.png',
#  'firenze_00104.png',
#  'bologna_01083.png',
#  'budapest_00575.png',
#  'toulouse_00423.png',
#  'leipzig_00214.png',
#  'torino_00212.png',
#  'torino_00527.png',
#  'berlin_00094.png',
#  'stuttgart_00083.png',
#  'barcelona_00175.png',
#  'pisa_00643.png',
#  'bratislava_00552.png',
#  'barcelona_00215.png',
#  'firenze_00974.png',
#  'hamburg_00641.png',
#  'roma_00869.png',
#  'nuernberg_00303.png',
#  'prague_01279.png']

# %%
index_id_list = find_index_of_images(ecp_img_df, image_name_list=train_img_ecp)

selected_ecp_img_df = create_img_df(ecp_img_df, index_id_list)
selected_ecp_ann_df = create_ann_df(ecp_ann_df, index_id_list)
print(selected_ecp_ann_df.shape[0])
print(selected_ecp_img_df.shape[0])
# Out:
# 7603
# 871

# %%
train_img_ecp
# Out:
# ['budapest_00163.png',
#  'barcelona_00775.png',
#  'marseille_01047.png',
#  'berlin_00002.png',
#  'barcelona_00707.png',
#  'barcelona_00620.png',
#  'brno_00954.png',
#  'amsterdam_00596.png',
#  'pisa_00040.png',
#  'ulm_00191.png',
#  'roma_00718.png',
#  'toulouse_00323.png',
#  'pisa_00085.png',
#  'bratislava_00750.png',
#  'ulm_00239.png',
#  'nuernberg_00012.png',
#  'ulm_00607.png',
#  'torino_00711.png',
#  'bologna_00575.png',
#  'montpellier_00256.png',
#  'barcelona_00239.png',
#  'prague_01081.png',
#  'hamburg_00049.png',
#  'montpellier_00041.png',
#  'ljubljana_00837.png',
#  'marseille_01183.png',
#  'milano_00827.png',
#  'barcelona_00585.png',
#  'amsterdam_00158.png',
#  'zagreb_00128.png',
#  'marseille_00319.png',
#  'toulouse_00618.png',
#  'potsdam_00197.png',
#  'marseille_01297.png',
#  'bologna_00086.png',
#  'amsterdam_00100.png',
#  'amsterdam_00138.png',
#  'torino_00490.png',
#  'firenze_00566.png',
#  'brno_00287.png',
#  'firenze_00389.png',
#  'milano_00574.png',
#  'budapest_00454.png',
#  'bologna_00425.png',
#  'potsdam_00466.png',
#  'prague_00216.png',
#  'nuernberg_00545.png',
#  'wuerzburg_00330.png',
#  'ljubljana_00552.png',
#  'marseille_01243.png',
#  'ljubljana_00500.png',
#  'torino_00565.png',
#  'zagreb_00432.png',
#  'bologna_01221.png',
#  'brno_00802.png',
#  'bologna_00352.png',
#  'nuernberg_00308.png',
#  'montpellier_00622.png',
#  'barcelona_00714.png',
#  'toulouse_00672.png',
#  'berlin_00212.png',
#  'ljubljana_00831.png',
#  'amsterdam_00136.png',
#  'firenze_00583.png',
#  'bratislava_00197.png',
#  'potsdam_00164.png',
#  'stuttgart_00491.png',
#  'stuttgart_00397.png',
#  'marseille_00952.png',
#  'brno_00353.png',
#  'prague_00281.png',
#  'szczecin_00040.png',
#  'bratislava_00237.png',
#  'amsterdam_01009.png',
#  'marseille_00046.png',
#  'hamburg_00423.png',
#  'nuernberg_00267.png',
#  'roma_00379.png',
#  'ljubljana_00720.png',
#  'bologna_00323.png',
#  'marseille_01023.png',
#  'marseille_00558.png',
#  'marseille_00276.png',
#  'barcelona_01066.png',
#  'szczecin_00004.png',
#  'nuernberg_00127.png',
#  'marseille_00590.png',
#  'roma_01089.png',
#  'brno_00477.png',
#  'nuernberg_00242.png',
#  'milano_00676.png',
#  'roma_01081.png',
#  'bologna_00266.png',
#  'roma_00659.png',
#  'firenze_00519.png',
#  'bratislava_00234.png',
#  'amsterdam_00532.png',
#  'koeln_00121.png',
#  'ulm_00576.png',
#  'dresden_00287.png',
#  'zagreb_00107.png',
#  'amsterdam_00798.png',
#  'montpellier_00390.png',
#  'torino_00912.png',
#  'szczecin_00160.png',
#  'torino_00176.png',
#  'leipzig_00174.png',
#  'marseille_01292.png',
#  'roma_00475.png',
#  'brno_00201.png',
#  'ulm_00184.png',
#  'zagreb_00298.png',
#  'bratislava_00282.png',
#  'roma_00684.png',
#  'dresden_00329.png',
#  'roma_00263.png',
#  'basel_00517.png',
#  'firenze_01128.png',
#  'torino_00303.png',
#  'ljubljana_00611.png',
#  'firenze_00710.png',
#  'firenze_00224.png',
#  'ulm_00342.png',
#  'basel_00373.png',
#  'barcelona_00243.png',
#  'montpellier_00490.png',
#  'budapest_00054.png',
#  'torino_00736.png',
#  'bratislava_00479.png',
#  'dresden_00575.png',
#  'bologna_00980.png',
#  'marseille_00051.png',
#  'ulm_00294.png',
#  'basel_00097.png',
#  'toulouse_00538.png',
#  'roma_00255.png',
#  'milano_00630.png',
#  'prague_01134.png',
#  'torino_00872.png',
#  'zuerich_00065.png',
#  'dresden_00662.png',
#  'toulouse_00427.png',
#  'berlin_00195.png',
#  'potsdam_00235.png',
#  'milano_00741.png',
#  'amsterdam_00269.png',
#  'berlin_00208.png',
#  'leipzig_00408.png',
#  'marseille_00940.png',
#  'hamburg_00422.png',
#  'milano_00371.png',
#  'ulm_00178.png',
#  'bratislava_00078.png',
#  'roma_00077.png',
#  'bratislava_00617.png',
#  'brno_00613.png',
#  'barcelona_00687.png',
#  'wuerzburg_00127.png',
#  'bratislava_00023.png',
#  'torino_00666.png',
#  'stuttgart_00061.png',
#  'brno_00126.png',
#  'firenze_00301.png',
#  'leipzig_00118.png',
#  'marseille_01118.png',
#  'hamburg_00630.png',
#  'ljubljana_00874.png',
#  'milano_00305.png',
#  'bratislava_00261.png',
#  'stuttgart_00437.png',
#  'amsterdam_00663.png',
#  'montpellier_00324.png',
#  'berlin_00043.png',
#  'roma_00415.png',
#  'pisa_00169.png',
#  'marseille_00544.png',
#  'barcelona_00877.png',
#  'bratislava_00458.png',
#  'firenze_00061.png',
#  'marseille_00955.png',
#  'nuernberg_00117.png',
#  'amsterdam_01033.png',
#  'prague_00557.png',
#  'ljubljana_00248.png',
#  'marseille_00528.png',
#  'dresden_00174.png',
#  'zuerich_00243.png',
#  'roma_00444.png',
#  'szczecin_00018.png',
#  'amsterdam_00951.png',
#  'nuernberg_00723.png',
#  'bratislava_00817.png',
#  'amsterdam_00509.png',
#  'zagreb_00111.png',
#  'prague_01016.png',
#  'milano_00664.png',
#  'dresden_00214.png',
#  'milano_00002.png',
#  'wuerzburg_00134.png',
#  'prague_00681.png',
#  'barcelona_00574.png',
#  'firenze_00915.png',
#  'budapest_00421.png',
#  'barcelona_00536.png',
#  'roma_01007.png',
#  'milano_00079.png',
#  'montpellier_00473.png',
#  'bologna_00449.png',
#  'ulm_00590.png',
#  'amsterdam_00492.png',
#  'koeln_00011.png',
#  'torino_00097.png',
#  'ljubljana_00773.png',
#  'budapest_00642.png',
#  'ljubljana_00246.png',
#  'milano_00789.png',
#  'koeln_00036.png',
#  'marseille_00834.png',
#  'nuernberg_00679.png',
#  'milano_00860.png',
#  'hamburg_00672.png',
#  'montpellier_00443.png',
#  'basel_00422.png',
#  'roma_01025.png',
#  'hamburg_00401.png',
#  'barcelona_00450.png',
#  'marseille_00219.png',
#  'bologna_00600.png',
#  'marseille_00376.png',
#  'roma_00597.png',
#  'koeln_00113.png',
#  'bologna_00983.png',
#  'firenze_00907.png',
#  'bratislava_00628.png',
#  'brno_00597.png',
#  'prague_01192.png',
#  'montpellier_00233.png',
#  'wuerzburg_00569.png',
#  'barcelona_00129.png',
#  'budapest_00102.png',
#  'wuerzburg_00551.png',
#  'stuttgart_00534.png',
#  'roma_00769.png',
#  'budapest_00193.png',
#  'ulm_00588.png',
#  'nuernberg_00059.png',
#  'dresden_00224.png',
#  'brno_00415.png',
#  'brno_00103.png',
#  'koeln_00118.png',
#  'hamburg_00421.png',
#  'bratislava_00066.png',
#  'prague_00437.png',
#  'bologna_00683.png',
#  'bologna_01032.png',
#  'amsterdam_00981.png',
#  'wuerzburg_00335.png',
#  'ljubljana_00371.png',
#  'marseille_01059.png',
#  'budapest_00075.png',
#  'firenze_00076.png',
#  'dresden_00544.png',
#  'ljubljana_00243.png',
#  'amsterdam_00127.png',
#  'montpellier_00592.png',
#  'montpellier_00179.png',
#  'barcelona_00297.png',
#  'bologna_00837.png',
#  'prague_01122.png',
#  'prague_00291.png',
#  'budapest_00700.png',
#  'basel_00288.png',
#  'leipzig_00045.png',
#  'nuernberg_00655.png',
#  'prague_01119.png',
#  'marseille_00044.png',
#  'dresden_00358.png',
#  'basel_00212.png',
#  'roma_00894.png',
#  'barcelona_00277.png',
#  'pisa_00133.png',
#  'marseille_01201.png',
#  'wuerzburg_00326.png',
#  'roma_00358.png',
#  'ulm_00196.png',
#  'budapest_00680.png',
#  'potsdam_00148.png',
#  'bologna_00089.png',
#  'firenze_00909.png',
#  'torino_00657.png',
#  'budapest_00784.png',
#  'nuernberg_00710.png',
#  'barcelona_01074.png',
#  'budapest_00147.png',
#  'ljubljana_00725.png',
#  'zuerich_00285.png',
#  'brno_00225.png',
#  'dresden_00736.png',
#  'koeln_00026.png',
#  'roma_00277.png',
#  'bratislava_00444.png',
#  'barcelona_00049.png',
#  'brno_00627.png',
#  'prague_01290.png',
#  'zagreb_00085.png',
#  'prague_00657.png',
#  'marseille_01085.png',
#  'milano_00021.png',
#  'marseille_00152.png',
#  'prague_01259.png',
#  'basel_00035.png',
#  'zagreb_00386.png',
#  'ulm_00459.png',
#  'hamburg_00019.png',
#  'firenze_00546.png',
#  'potsdam_00056.png',
#  'bologna_00732.png',
#  'hamburg_00348.png',
#  'basel_00005.png',
#  'torino_00353.png',
#  'roma_00843.png',
#  'marseille_00552.png',
#  'marseille_00445.png',
#  'nuernberg_00109.png',
#  'wuerzburg_00271.png',
#  'potsdam_00475.png',
#  'toulouse_00039.png',
#  'toulouse_00090.png',
#  'marseille_01221.png',
#  'firenze_01022.png',
#  'hamburg_00427.png',
#  'hamburg_00299.png',
#  'dresden_00057.png',
#  'barcelona_00905.png',
#  'montpellier_00553.png',
#  'ljubljana_00865.png',
#  'amsterdam_00805.png',
#  'pisa_00546.png',
#  'torino_00649.png',
#  'milano_00683.png',
#  'pisa_00130.png',
#  'torino_00573.png',
#  'barcelona_00869.png',
#  'amsterdam_00695.png',
#  'ulm_00174.png',
#  'leipzig_00331.png',
#  'potsdam_00439.png',
#  'marseille_01097.png',
#  'prague_00914.png',
#  'nuernberg_00614.png',
#  'bologna_00611.png',
#  'prague_00550.png',
#  'marseille_00236.png',
#  'basel_00456.png',
#  'zuerich_00355.png',
#  'barcelona_00486.png',
#  'leipzig_00228.png',
#  'szczecin_00259.png',
#  'hamburg_00123.png',
#  'firenze_00538.png',
#  'roma_00417.png',
#  'firenze_00110.png',
#  'firenze_00490.png',
#  'montpellier_00566.png',
#  'budapest_00019.png',
#  'roma_00034.png',
#  'leipzig_00306.png',
#  'marseille_01043.png',
#  'firenze_00867.png',
#  'basel_00625.png',
#  'barcelona_00455.png',
#  'montpellier_00180.png',
#  'barcelona_01239.png',
#  'potsdam_00480.png',
#  'prague_00468.png',
#  'bologna_00648.png',
#  'bologna_01063.png',
#  'milano_00255.png',
#  'wuerzburg_00197.png',
#  'bratislava_00402.png',
#  'marseille_00518.png',
#  'bologna_00534.png',
#  'szczecin_00027.png',
#  'dresden_00574.png',
#  'barcelona_00613.png',
#  'barcelona_00566.png',
#  'prague_00003.png',
#  'milano_00601.png',
#  'bologna_01018.png',
#  'bologna_00368.png',
#  'stuttgart_00345.png',
#  'roma_00602.png',
#  'barcelona_00890.png',
#  'nuernberg_00226.png',
#  'toulouse_00458.png',
#  'brno_00514.png',
#  'prague_00268.png',
#  'amsterdam_00328.png',
#  'firenze_00810.png',
#  'potsdam_00451.png',
#  'prague_01295.png',
#  'zagreb_00420.png',
#  'potsdam_00158.png',
#  'roma_00844.png',
#  'nuernberg_00020.png',
#  'dresden_00364.png',
#  'bratislava_00089.png',
#  'roma_00155.png',
#  'bologna_00393.png',
#  'dresden_00487.png',
#  'prague_01111.png',
#  'prague_01008.png',
#  'montpellier_00431.png',
#  'montpellier_00357.png',
#  'toulouse_00375.png',
#  'roma_00882.png',
#  'wuerzburg_00565.png',
#  'firenze_00454.png',
#  'budapest_00155.png',
#  'hamburg_00100.png',
#  'roma_01093.png',
#  'ljubljana_00362.png',
#  'dresden_00620.png',
#  'prague_01240.png',
#  'zagreb_00381.png',
#  'potsdam_00138.png',
#  'zuerich_00365.png',
#  'pisa_00218.png',
#  'barcelona_01030.png',
#  'amsterdam_00358.png',
#  'pisa_00138.png',
#  'budapest_00067.png',
#  'zagreb_00632.png',
#  'dresden_00204.png',
#  'marseille_00490.png',
#  'milano_00511.png',
#  'nuernberg_00508.png',
#  'milano_00668.png',
#  'roma_00001.png',
#  'roma_00532.png',
#  'roma_00087.png',
#  'amsterdam_00685.png',
#  'roma_01063.png',
#  'torino_00559.png',
#  'bratislava_00115.png',
#  'torino_00477.png',
#  'roma_00895.png',
#  'amsterdam_00468.png',
#  'ljubljana_00842.png',
#  'torino_00739.png',
#  'dresden_00357.png',
#  'toulouse_00420.png',
#  'hamburg_00252.png',
#  'prague_00209.png',
#  'prague_00533.png',
#  'pisa_00084.png',
#  'ljubljana_00644.png',
#  'montpellier_00100.png',
#  'barcelona_01236.png',
#  'berlin_00088.png',
#  'zagreb_00168.png',
#  'bologna_00367.png',
#  'torino_00159.png',
#  'prague_00272.png',
#  'wuerzburg_00248.png',
#  'roma_00834.png',
#  'pisa_00558.png',
#  'nuernberg_00528.png',
#  'barcelona_01073.png',
#  'firenze_00540.png',
#  'toulouse_00516.png',
#  'firenze_00028.png',
#  'lyon_00027.png',
#  'berlin_00071.png',
#  'marseille_00738.png',
#  'bratislava_00161.png',
#  'milano_00120.png',
#  'zagreb_00419.png',
#  'bologna_00801.png',
#  'toulouse_00210.png',
#  'brno_00086.png',
#  'stuttgart_00220.png',
#  'ljubljana_00429.png',
#  'pisa_00327.png',
#  'ljubljana_00004.png',
#  'barcelona_00066.png',
#  'nuernberg_00386.png',
#  'wuerzburg_00033.png',
#  'hamburg_00087.png',
#  'hamburg_00414.png',
#  'marseille_00853.png',
#  'roma_00066.png',
#  'bologna_01006.png',
#  'basel_00048.png',
#  'wuerzburg_00123.png',
#  'nuernberg_00006.png',
#  'berlin_00075.png',
#  'hamburg_00153.png',
#  'milano_00133.png',
#  'wuerzburg_00234.png',
#  'ulm_00113.png',
#  'prague_00407.png',
#  'bologna_00110.png',
#  'montpellier_00087.png',
#  'torino_00204.png',
#  'lyon_00121.png',
#  'brno_00057.png',
#  'toulouse_00187.png',
#  'ljubljana_00745.png',
#  'torino_00186.png',
#  'bologna_00843.png',
#  'torino_00730.png',
#  'dresden_00527.png',
#  'budapest_00699.png',
#  'amsterdam_00214.png',
#  'nuernberg_00492.png',
#  'barcelona_01238.png',
#  'ljubljana_00099.png',
#  'bratislava_00048.png',
#  'firenze_00952.png',
#  'potsdam_00027.png',
#  'toulouse_00428.png',
#  'firenze_00154.png',
#  'bologna_00953.png',
#  'prague_00630.png',
#  'amsterdam_00183.png',
#  'barcelona_00598.png',
#  'amsterdam_00193.png',
#  'prague_01341.png',
#  'stuttgart_00521.png',
#  'szczecin_00187.png',
#  'leipzig_00067.png',
#  'toulouse_00033.png',
#  'ljubljana_00213.png',
#  'koeln_00183.png',
#  'brno_00832.png',
#  'szczecin_00181.png',
#  'prague_00560.png',
#  'nuernberg_00080.png',
#  'brno_00743.png',
#  'brno_00179.png',
#  'basel_00222.png',
#  'prague_00665.png',
#  'amsterdam_00630.png',
#  'basel_00134.png',
#  'zagreb_00502.png',
#  'barcelona_00112.png',
#  'firenze_01143.png',
#  'basel_00103.png',
#  'prague_01172.png',
#  'torino_00696.png',
#  'koeln_00047.png',
#  'potsdam_00130.png',
#  'ljubljana_00600.png',
#  'zagreb_00187.png',
#  'hamburg_00198.png',
#  'leipzig_00069.png',
#  'basel_00128.png',
#  'basel_00106.png',
#  'amsterdam_00284.png',
#  'roma_00934.png',
#  'dresden_00136.png',
#  'barcelona_00122.png',
#  'dresden_00316.png',
#  'torino_00713.png',
#  'milano_00344.png',
#  'firenze_00194.png',
#  'torino_00410.png',
#  'firenze_00722.png',
#  'wuerzburg_00449.png',
#  'milano_00374.png',
#  'torino_00401.png',
#  'stuttgart_00024.png',
#  'roma_00760.png',
#  'dresden_00103.png',
#  'barcelona_01049.png',
#  'szczecin_00374.png',
#  'toulouse_00089.png',
#  'firenze_00025.png',
#  'marseille_00976.png',
#  'bologna_00642.png',
#  'marseille_00634.png',
#  'barcelona_01203.png',
#  'milano_00350.png',
#  'nuernberg_00549.png',
#  'stuttgart_00157.png',
#  'brno_00543.png',
#  'dresden_00514.png',
#  'koeln_00044.png',
#  'marseille_00549.png',
#  'roma_00124.png',
#  'amsterdam_00879.png',
#  'brno_00878.png',
#  'brno_00655.png',
#  'dresden_00628.png',
#  'wuerzburg_00132.png',
#  'torino_00683.png',
#  'zagreb_00544.png',
#  'barcelona_00395.png',
#  'dresden_00548.png',
#  'barcelona_00303.png',
#  'nuernberg_00282.png',
#  'marseille_01150.png',
#  'barcelona_00726.png',
#  'brno_00702.png',
#  'milano_00750.png',
#  'leipzig_00428.png',
#  'prague_00411.png',
#  'budapest_00038.png',
#  'lyon_00107.png',
#  'marseille_00066.png',
#  'montpellier_00288.png',
#  'torino_00817.png',
#  'marseille_00618.png',
#  'wuerzburg_00347.png',
#  'ljubljana_00202.png',
#  'bratislava_00622.png',
#  'toulouse_00507.png',
#  'marseille_00416.png',
#  'dresden_00657.png',
#  'marseille_00101.png',
#  'roma_00802.png',
#  'montpellier_00393.png',
#  'leipzig_00145.png',
#  'potsdam_00031.png',
#  'potsdam_00029.png',
#  'bologna_00212.png',
#  'firenze_00745.png',
#  'zagreb_00129.png',
#  'dresden_00245.png',
#  'basel_00627.png',
#  'hamburg_00375.png',
#  'bologna_00733.png',
#  'montpellier_00310.png',
#  'roma_00339.png',
#  'hamburg_00154.png',
#  'ljubljana_00312.png',
#  'brno_00915.png',
#  'prague_00674.png',
#  'marseille_00215.png',
#  'nuernberg_00298.png',
#  'firenze_00866.png',
#  'roma_01032.png',
#  'prague_00881.png',
#  'prague_00152.png',
#  'leipzig_00238.png',
#  'ljubljana_00158.png',
#  'ulm_00322.png',
#  'firenze_00143.png',
#  'barcelona_00321.png',
#  'brno_00476.png',
#  'ljubljana_00632.png',
#  'hamburg_00668.png',
#  'potsdam_00206.png',
#  'amsterdam_00472.png',
#  'zuerich_00193.png',
#  'roma_00620.png',
#  'prague_00116.png',
#  'wuerzburg_00016.png',
#  'bologna_00313.png',
#  'stuttgart_00273.png',
#  'dresden_00656.png',
#  'basel_00061.png',
#  'bologna_01185.png',
#  'wuerzburg_00139.png',
#  'hamburg_00340.png',
#  'barcelona_00177.png',
#  'firenze_00218.png',
#  'stuttgart_00275.png',
#  'zagreb_00473.png',
#  'firenze_00452.png',
#  'bologna_00908.png',
#  'budapest_00266.png',
#  'toulouse_00520.png',
#  'prague_00264.png',
#  'bratislava_00710.png',
#  'budapest_00156.png',
#  'wuerzburg_00292.png',
#  'brno_00176.png',
#  'prague_00697.png',
#  'zagreb_00505.png',
#  'prague_00483.png',
#  'amsterdam_00634.png',
#  'bologna_00877.png',
#  'stuttgart_00545.png',
#  'marseille_01169.png',
#  'ljubljana_00625.png',
#  'marseille_00675.png',
#  'montpellier_00224.png',
#  'lyon_00017.png',
#  'bratislava_00045.png',
#  'hamburg_00523.png',
#  'potsdam_00103.png',
#  'brno_00257.png',
#  'wuerzburg_00577.png',
#  'hamburg_00357.png',
#  'roma_00971.png',
#  'barcelona_00083.png',
#  'koeln_00000.png',
#  'bratislava_00521.png',
#  'szczecin_00232.png',
#  'barcelona_00770.png',
#  'bologna_01168.png',
#  'milano_00802.png',
#  'pisa_00520.png',
#  'bratislava_00189.png',
#  'basel_00052.png',
#  'dresden_00516.png',
#  'stuttgart_00416.png',
#  'marseille_00997.png',
#  'szczecin_00301.png',
#  'montpellier_00103.png',
#  'marseille_00730.png',
#  'budapest_00696.png',
#  'budapest_00688.png',
#  'ulm_00580.png',
#  'montpellier_00504.png',
#  'potsdam_00252.png',
#  'berlin_00306.png',
#  'bologna_01122.png',
#  'firenze_01052.png',
#  'torino_00279.png',
#  'ulm_00134.png',
#  'pisa_00568.png',
#  'torino_00066.png',
#  'roma_00259.png',
#  'prague_01159.png',
#  'firenze_00196.png',
#  'roma_00798.png',
#  'ljubljana_00742.png',
#  'bratislava_00483.png',
#  'firenze_01051.png',
#  'prague_00091.png',
#  'torino_00926.png',
#  'roma_00965.png',
#  'hamburg_00535.png',
#  'leipzig_00305.png',
#  'bologna_00764.png',
#  'torino_00143.png',
#  'zagreb_00491.png',
#  'milano_00488.png',
#  'prague_00957.png',
#  'marseille_01093.png',
#  'hamburg_00129.png',
#  'toulouse_00037.png',
#  'firenze_00471.png',
#  'roma_00390.png',
#  'marseille_00187.png',
#  'barcelona_00308.png',
#  'potsdam_00244.png',
#  'potsdam_00075.png',
#  'ulm_00314.png',
#  'brno_00244.png',
#  'bologna_00159.png',
#  'stuttgart_00399.png',
#  'dresden_00107.png',
#  'ljubljana_00630.png',
#  'barcelona_00431.png',
#  'stuttgart_00069.png',
#  'firenze_00248.png',
#  'wuerzburg_00344.png',
#  'bologna_00989.png',
#  'firenze_00222.png',
#  'dresden_00594.png',
#  'amsterdam_00590.png',
#  'amsterdam_00302.png',
#  'basel_00382.png',
#  'brno_00455.png',
#  'budapest_00288.png',
#  'firenze_00219.png',
#  'zagreb_00573.png',
#  'roma_00471.png',
#  'marseille_00460.png',
#  'nuernberg_00494.png',
#  'basel_00094.png',
#  'marseille_00768.png',
#  'pisa_00187.png',
#  'nuernberg_00513.png',
#  'stuttgart_00046.png',
#  'firenze_00558.png',
#  'milano_00237.png',
#  'toulouse_00195.png',
#  'bratislava_00205.png',
#  'roma_00310.png',
#  'roma_00811.png',
#  'ulm_00350.png',
#  'barcelona_01075.png',
#  'stuttgart_00465.png',
#  'nuernberg_00339.png',
#  'barcelona_01037.png',
#  'prague_00137.png',
#  'ulm_00280.png',
#  'leipzig_00263.png',
#  'budapest_00149.png',
#  'firenze_00340.png',
#  'budapest_00361.png',
#  'bologna_00970.png',
#  'berlin_00331.png',
#  'bologna_00334.png',
#  'brno_00758.png',
#  'milano_00739.png',
#  'dresden_00104.png',
#  'budapest_00212.png',
#  'zuerich_00054.png',
#  'marseille_00278.png',
#  'firenze_00096.png',
#  'bratislava_00730.png',
#  'amsterdam_00272.png',
#  'budapest_00239.png',
#  'amsterdam_00615.png',
#  'brno_00603.png',
#  'marseille_00663.png',
#  'brno_00704.png',
#  'montpellier_00432.png',
#  'zagreb_00204.png',
#  'dresden_00284.png',
#  'berlin_00374.png',
#  'barcelona_00725.png',
#  'zagreb_00338.png',
#  'szczecin_00174.png',
#  'potsdam_00182.png',
#  'barcelona_01126.png',
#  'ulm_00291.png',
#  'nuernberg_00726.png',
#  'nuernberg_00347.png',
#  'pisa_00407.png',
#  'nuernberg_00505.png',
#  'berlin_00204.png',
#  'lyon_00038.png',
#  'budapest_00175.png',
#  'prague_00498.png',
#  'ljubljana_00541.png',
#  'marseille_00992.png',
#  'marseille_00499.png',
#  'montpellier_00327.png',
#  'stuttgart_00267.png',
#  'torino_00089.png',
#  'pisa_00477.png',
#  'bologna_01074.png',
#  'ljubljana_00276.png',
#  'barcelona_00463.png',
#  'prague_00030.png',
#  'torino_00956.png',
#  'zagreb_00597.png',
#  'ljubljana_00862.png',
#  'torino_00690.png',
#  'firenze_01112.png',
#  'budapest_00768.png',
#  'leipzig_00068.png',
#  'bologna_00921.png',
#  'montpellier_00378.png',
#  'milano_00659.png',
#  'roma_00996.png',
#  'firenze_00104.png',
#  'bologna_01083.png',
#  'budapest_00575.png',
#  'toulouse_00423.png',
#  'leipzig_00214.png',
#  'torino_00212.png',
#  'torino_00527.png',
#  'berlin_00094.png',
#  'stuttgart_00083.png',
#  'barcelona_00175.png',
#  'pisa_00643.png',
#  'bratislava_00552.png',
#  'barcelona_00215.png',
#  'firenze_00974.png',
#  'hamburg_00641.png',
#  'roma_00869.png',
#  'nuernberg_00303.png',
#  'prague_01279.png']

# %%
pd.set_option('display.max_colwidth', None)
selected_ecp_img_df.file_name
# Out:
# 3296       EuroCity/ECP/day/img/train/budapest/budapest_00163.png
# 19576    EuroCity/ECP/day/img/train/barcelona/barcelona_00775.png
# 12594    EuroCity/ECP/day/img/train/marseille/marseille_01047.png
# 4347           EuroCity/ECP/day/img/train/berlin/berlin_00002.png
# 19954    EuroCity/ECP/day/img/train/barcelona/barcelona_00707.png
#                                    ...
# 7095         EuroCity/ECP/day/img/train/firenze/firenze_00974.png
# 14150        EuroCity/ECP/day/img/train/hamburg/hamburg_00641.png
# 9118               EuroCity/ECP/day/img/train/roma/roma_00869.png
# 22630    EuroCity/ECP/day/img/train/nuernberg/nuernberg_00303.png
# 16379          EuroCity/ECP/day/img/train/prague/prague_01279.png
# Name: file_name, Length: 871, dtype: object

# %%
print(f'add #{selected_ecp_img_df.shape[0]} images to #{aug_img_df.shape[0]} train set')
aug_img_df, selected_ecp_ann_df = uodate_id_in_image_ann(selected_ecp_img_df, aug_img_df, selected_ecp_ann_df)
print(f'train img df after aug shape: {aug_img_df.shape[0]}')
# Out:
# add #871 images to #2529 train set
# train img df after aug shape: 3400

# %%
selected_ecp_ann_df = add_area(selected_ecp_ann_df)
print(f'add #{selected_ecp_ann_df.shape[0]} annotations to #{cp_ann_df.shape[0]} train set')
ann_df_c = concat_ann_df(cp_ann_df, selected_ecp_ann_df)
for idx, row in ann_df_c.iterrows():
    assert idx + 1 == row['id']
print(f'train annotations #{ann_df_c.shape[0]} for train set after augmentation')
# Out:
# add #7603 annotations to #23429 train set
# train annotations #31032 for train set after augmentation

# %% [markdown]
# ### crowdHuman

# %%
ch_file = 'json_files/CrowdHuman/train.json'

f = open(ch_file)
ch_data = json.load(f)
# ch_licenses = ch_data['licenses']
ch_categories = ch_data['categories']
ch_images = ch_data['images']
ch_annotations = ch_data['annotations']
ch_img_df = pd.DataFrame(ch_images)
ch_ann_df = pd.DataFrame(ch_annotations)

# %%
print(ch_data['categories'])
# Out:
# [{'supercategory': 'none', 'id': 1, 'name': 'person'}, {'supercategory': 'none', 'id': 2, 'name': 'mask'}]

# %%
bb_df = copy.deepcopy(ch_ann_df[ch_ann_df.category_id == 1])
ch_ann_df = bb_df.copy()
ch_ann_df
# Out:
#           area  iscrowd  image_id                   bbox  \
# 0        86523        0         1    [61, 123, 191, 453]
# 1        92378        0         1    [165, 95, 187, 494]
# 2        96135        0         1   [236, 104, 195, 493]
# 3        85852        0         1   [452, 110, 169, 508]
# 4        62103        0         1    [520, 95, 163, 381]
# ...        ...      ...       ...                    ...
# 438781  286612        0     15000  [3393, 590, 316, 907]
# 438782   81890        0     15000  [3448, 607, 190, 431]
# 438783  240570        0     15000  [3684, 554, 297, 810]
# 438784  234855        0     15000  [3797, 536, 255, 921]
# 438785  241056        0     15000  [3863, 544, 248, 972]
#
#                          hbox                   vbox  category_id      id  \
# 0          [123, 129, 63, 64]    [62, 126, 154, 446]            1       1
# 1           [214, 97, 58, 74]    [175, 95, 140, 487]            1       2
# 2          [318, 109, 58, 68]   [260, 106, 170, 487]            1       3
# 3          [486, 119, 61, 74]   [455, 113, 141, 501]            1       4
# 4          [559, 105, 53, 57]     [553, 98, 70, 118]            1       5
# ...                       ...                    ...          ...     ...
# 438781  [3518, 595, 114, 133]  [3393, 590, 316, 907]            1  438782
# 438782   [3511, 610, 93, 104]  [3452, 608, 184, 430]            1  438783
# 438783   [3824, 559, 96, 105]  [3795, 559, 156, 794]            1  438784
# 438784   [3909, 539, 89, 113]  [3889, 535, 112, 169]            1  438785
# 438785   [3954, 561, 98, 126]  [3863, 544, 137, 972]            1  438786
#
#         ignore
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 438781       0
# 438782       0
# 438783       0
# 438784       0
# 438785       0
#
# [352983 rows x 9 columns]

# %%
for idx, row in ch_img_df.iterrows():
    ch_img_df.at[ch_img_df.index[idx], 'file_name'] = 'CrowdHuman/Images/' + ch_img_df.at[ch_img_df.index[idx], 'file_name']
ch_img_df
# Out:
#                                             file_name  height  width     id
# 0        CrowdHuman/Images/284193,faa9000f2678b5e.jpg     683   1024      1
# 1       CrowdHuman/Images/273275,cd061000af95f691.jpg     480    600      2
# 2       CrowdHuman/Images/273278,8d231000e09fc133.jpg    1017   1300      3
# 3       CrowdHuman/Images/283554,2cd4d0007833968d.jpg     954   1300      4
# 4       CrowdHuman/Images/283554,37ba1000a6ca8c4d.jpg     533    800      5
# ...                                               ...     ...    ...    ...
# 14995   CrowdHuman/Images/273275,874d9000417e16ed.jpg    1192   1800  14996
# 14996   CrowdHuman/Images/273278,d329e000260a8cc2.jpg     600   1800  14997
# 14997   CrowdHuman/Images/282555,c5fd20007faf5f84.jpg     575   1024  14998
# 14998  CrowdHuman/Images/273275,10b78d0006d7d7b9c.jpg     462   1838  14999
# 14999   CrowdHuman/Images/284193,2e02d0003abd1bb1.jpg    1912   4000  15000
#
# [15000 rows x 4 columns]

# %%
train_img_ch, val_img_ch, test_img_ch = splite_data(ch_img_df, train_size=436, val_size=94, test_size=94, examption_list=ch_list)

# %%
index_id_list = find_index_of_images(ch_img_df, image_name_list=train_img_ch)
selected_ch_img_df = create_img_df(ch_img_df, index_id_list)
selected_ch_ann_df = create_ann_df(ch_ann_df, index_id_list)
selected_ch_img_df
# Out:
#                                             file_name  height  width     id
# 14404  CrowdHuman/Images/273278,1339ba0003a171bf2.jpg     600    450  14405
# 13855  CrowdHuman/Images/273278,1001db000895beed8.jpg     447    640  13856
# 3591    CrowdHuman/Images/273278,5a9ea000ba06ed2b.jpg     467    700   3592
# 4175    CrowdHuman/Images/284193,25adc0004771188c.jpg     480    852   4176
# 12240    CrowdHuman/Images/273275,b69d0008c7203d2.jpg     552    980  12241
# ...                                               ...     ...    ...    ...
# 7258   CrowdHuman/Images/273278,12dd0000060b74783.jpg    1080   1920   7259
# 6416   CrowdHuman/Images/273278,1190b7000c4ef9ce4.jpg     848   1200   6417
# 12623   CrowdHuman/Images/282555,e2e15000a97c1b22.jpg     956   1300  12624
# 9086    CrowdHuman/Images/282555,6668d00018c6d6f1.jpg     866   1300   9087
# 14178   CrowdHuman/Images/284193,193b9000f3131ff5.jpg     480    910  14179
#
# [436 rows x 4 columns]

# %%
print(selected_ch_img_df.shape[0])
selected_ch_ann_df.shape[0]
# Out:
# 436
# 9483

# %%
print(f'add #{selected_ch_img_df.shape[0]} images to #{aug_img_df.shape[0]} train set')
aug_img_df, selected_ch_ann_df = uodate_id_in_image_ann(selected_ch_img_df, aug_img_df, selected_ch_ann_df, dt='ch')
print(f'train img df after aug shape: {aug_img_df.shape[0]}')
# Out:
# add #436 images to #3400 train set
# train img df after aug shape: 3836

# %%
selected_ch_ann_df.shape[0]
# Out:
# 9483

# %%
selected_ch_ann_df = add_area(selected_ch_ann_df)
print(f'add #{selected_ch_ann_df.shape[0]} annotations to #{ann_df_c.shape[0]} train set')
ann_df_c = concat_ann_df(ann_df_c, selected_ch_ann_df)
ann_df_c = ann_df_c.drop(['hbox', 'vbox'], axis = 1)
print(f'train annotations #{ann_df_c.shape[0]} for train set after augmentation')
# Out:
# add #9483 annotations to #31032 train set
# train annotations #40515 for train set after augmentation

# %% [markdown]
# ### wheelchair

# %%
wheel_file = '/home/test_pc/mmlab/mmdetection/datasets/selected_oi/train.json'

f = open(wheel_file)
wheel_data = json.load(f)
wheel_categories = wheel_data['categories']
wheel_images = wheel_data['images']
wheel_annotations = wheel_data['annotations']
wheel_img_df = pd.DataFrame(wheel_images)
wheel_ann_df = pd.DataFrame(wheel_annotations)
print(wheel_img_df.shape[0])
# Out:
# 20

# %%
wheel_img_df
# Out:
#     id                                      file_name  width  height  \
# 0    1  selected_oi/images/train/0001e595b536c9ec.jpg   1024     768
# 1    2  selected_oi/images/train/0001fa6ab562fd2a.jpg   1022    1024
# 2    3  selected_oi/images/train/0000b4b26ef88376.jpg   1024     717
# 3    4  selected_oi/images/train/0001c626b9afb50c.jpg   1024     675
# 4    5  selected_oi/images/train/0000a90019e380dc.jpg   1024     731
# 5    6  selected_oi/images/train/0000c4f95a9d5a54.jpg   1011    1024
# 6    7  selected_oi/images/train/00006bdb1eb5cd74.jpg   1024     681
# 7    8  selected_oi/images/train/0000bcb094764718.jpg   1024     576
# 8    9  selected_oi/images/train/0001b46b0b82ee29.jpg   1024     683
# 9   10  selected_oi/images/train/0000f53faa4d14c3.jpg   1024     683
# 10  11  selected_oi/images/train/0001c43f78cd23e1.jpg   1024     683
# 11  12  selected_oi/images/train/00003e2837c7b728.jpg   1024     689
# 12  13  selected_oi/images/train/00006b13c052138f.jpg   1024     683
# 13  14  selected_oi/images/train/0000eb5027281f2a.jpg   1024     683
# 14  15  selected_oi/images/train/00004b19ca2c952f.jpg   1024     683
# 15  16  selected_oi/images/train/0000fcb8ed0ea243.jpg   1024     683
# 16  17  selected_oi/images/train/0001d48938a45d49.jpg   1024     683
# 17  18  selected_oi/images/train/0000ce19115ae401.jpg   1024     786
# 18  19  selected_oi/images/train/00005e7429a94ad4.jpg   1024     768
# 19  20  selected_oi/images/train/00001bcc92282a38.jpg   1024     683
#
#                  date_captured  license coco_url flickr_url
# 0   2021-04-18 13:58:02.810552        1
# 1   2021-04-18 13:58:02.810552        1
# 2   2021-04-18 13:58:02.810552        1
# 3   2021-04-18 13:58:02.810552        1
# 4   2021-04-18 13:58:02.810552        1
# 5   2021-04-18 13:58:02.810552        1
# 6   2021-04-18 13:58:02.810552        1
# 7   2021-04-18 13:58:02.810552        1
# 8   2021-04-18 13:58:02.810552        1
# 9   2021-04-18 13:58:02.810552        1
# 10  2021-04-18 13:58:02.810552        1
# 11  2021-04-18 13:58:02.810552        1
# 12  2021-04-18 13:58:02.810552        1
# 13  2021-04-18 13:58:02.810552        1
# 14  2021-04-18 13:58:02.810552        1
# 15  2021-04-18 13:58:02.810552        1
# 16  2021-04-18 13:58:02.810552        1
# 17  2021-04-18 13:58:02.810552        1
# 18  2021-04-18 13:58:02.810552        1
# 19  2021-04-18 13:58:02.810552        1

# %%
print(wheel_data['categories'])
# Out:
# [{'id': 1, 'name': 'pedestrain', 'supercategory': 'pedestrain'}]

# %%
wheel_ann_df = add_area(wheel_ann_df)

print(wheel_ann_df.shape[0])
# Out:
# 46

# %%
selected_img_df = copy.deepcopy(wheel_img_df)
selected_ann_df = copy.deepcopy(wheel_ann_df)

# %%
print(f'add #{selected_img_df.shape[0]} images to #{aug_img_df.shape[0]} train set')
aug_img_df, selected_ann_df = uodate_id_in_image_ann(selected_img_df, aug_img_df, selected_ann_df)
print(f'train img df after aug shape: {aug_img_df.shape[0]}')
# Out:
# add #20 images to #3836 train set
# train img df after aug shape: 3856

# %%
print(f'add #{selected_ann_df.shape[0]} annotations to #{ann_df_c.shape[0]} train set')
ann_df_c = concat_ann_df(ann_df_c, selected_ann_df)
print(f'train annotations #{ann_df_c.shape[0]} for train set after augmentation')
# Out:
# add #46 annotations to #40515 train set
# train annotations #40561 for train set after augmentation

# %%
for idx, row in ann_df_c.iterrows():
    assert idx + 1 == row['id']

# %% [markdown]
# ### WP

# %%
wp1_file = 'json_files/WiderPerson/train.json'

f = open(wp1_file)
wp_data = json.load(f)
wp_categories = wp_data['categories']
wp_images = wp_data['images']
wp_annotations = wp_data['annotations']
wp_img_df = pd.DataFrame(wp_images)
wp_ann_df = pd.DataFrame(wp_annotations)
wp_img_df.shape[0]
# Out:
# 8000

# %%
wp_ann_df
# Out:
#             id  image_id  category_id  iscrowd                         bbox  \
# 0            1         1            1    False    [45.0, 235.0, 34.0, 83.0]
# 1            2         1            1    False   [60.0, 209.0, 60.0, 147.0]
# 2            3         1            1    False  [119.0, 214.0, 49.0, 122.0]
# 3            4         1            1    False   [94.0, 220.0, 42.0, 106.0]
# 4            5         1            1    False  [213.0, 201.0, 74.0, 180.0]
# ...        ...       ...          ...      ...                          ...
# 241804  241805      8000            1    False    [233.0, 83.0, 15.0, 18.0]
# 241805  241806      8000            1    False     [34.0, 88.0, 18.0, 40.0]
# 241806  241807      8000            1    False     [66.0, 87.0, 15.0, 27.0]
# 241807  241808      8000            1    False    [161.0, 79.0, 16.0, 21.0]
# 241808  241809      8000            1    False    [141.0, 70.0, 16.0, 15.0]
#
#         width  height
# 0         550     413
# 1         550     413
# 2         550     413
# 3         550     413
# 4         550     413
# ...       ...     ...
# 241804    385     257
# 241805    385     257
# 241806    385     257
# 241807    385     257
# 241808    385     257
#
# [241809 rows x 7 columns]

# %%
print(wp_data['categories'])
# Out:
# [{'id': 1, 'name': 'pedestrain', 'supercategory': 'pedestrain'}]

# %%
train_img_wp, val_img_wp, test_img_wp = splite_data(wp_img_df, train_size=351, val_size=75,test_size=75, examption_list=wp_list)
index_id_list = find_index_of_images(wp_img_df, image_name_list=train_img_wp)

# %%
selected_wp_img_df = create_img_df(wp_img_df, index_id_list)
selected_wp_img_df.shape[0]
# Out:
# 351

# %%
selected_wp_ann_df = create_ann_df(wp_ann_df, index_id_list)
selected_wp_ann_df = add_area(selected_wp_ann_df)
selected_wp_ann_df.shape[0]
# Out:
# 10843

# %%
print(f'add #{selected_wp_img_df.shape[0]} images to #{aug_img_df.shape[0]} train set')
aug_img_df, selected_wp_ann_df = uodate_id_in_image_ann(selected_wp_img_df, aug_img_df, selected_wp_ann_df)
print(f'train img df after aug shape: {aug_img_df.shape[0]}')
# Out:
# add #351 images to #3856 train set
# train img df after aug shape: 4207

# %%
selected_wp_ann_df.shape[0]
# Out:
# 10843

# %%
print(f'add #{selected_wp_ann_df.shape[0]} annotations to #{ann_df_c.shape[0]} train set')

ann_df_c = concat_ann_df(ann_df_c, selected_wp_ann_df)

for idx, row in ann_df_c.iterrows():
    assert idx + 1 == row['id']
print(f'train annotations #{ann_df_c.shape[0]} for train set after augmentation')
# Out:
# add #10843 annotations to #40561 train set
# train annotations #51404 for train set after augmentation

# %%
ann_df_c.shape[0]
# Out:
# 51404

# %%
ann_df_c
# Out:
#           id  image_id  category_id  iscrowd                         bbox  \
# 0          1         1            1        1  [1034.0, 366.0, 31.0, 75.0]
# 1          2         1            1        1  [1911.0, 359.0, 10.0, 54.0]
# 2          3         1            1        1    [1137.0, 307.0, 8.0, 9.0]
# 3          4         2            1        0  [602.0, 413.0, 60.0, 146.0]
# 4          5         2            1        0  [281.0, 381.0, 89.0, 216.0]
# ...      ...       ...          ...      ...                          ...
# 51399  51400      3966            1        0   [314.0, 140.0, 27.0, 34.0]
# 51400  51401      3966            1        0   [315.0, 105.0, 16.0, 32.0]
# 51401  51402      3966            1        0   [256.0, 105.0, 28.0, 18.0]
# 51402  51403      3966            1        0   [227.0, 107.0, 20.0, 18.0]
# 51403  51404      3966            1        0    [208.0, 97.0, 17.0, 18.0]
#
#       width height   area  ignore
# 0      2048   1024   2325     NaN
# 1      2048   1024    540     NaN
# 2      2048   1024     72     NaN
# 3      2048   1024   8760     NaN
# 4      2048   1024  19224     NaN
# ...     ...    ...    ...     ...
# 51399   550    366    918     NaN
# 51400   550    366    512     NaN
# 51401   550    366    504     NaN
# 51402   550    366    360     NaN
# 51403   550    366    306     NaN
#
# [51404 rows x 9 columns]

# %% [markdown]
# #### selected caltech

# %%
ca_file = '/home/test_pc/mmlab/mmdetection/datasets/rand_cal/train.json'

f = open(ca_file)
cl_data = json.load(f)
cl_categories = cl_data['categories']
cl_images = cl_data['images']
cl_annotations = cl_data['annotations']
cl_img_df = pd.DataFrame(cl_images)
cl_ann_df = pd.DataFrame(cl_annotations)
cl_img_df
# Out:
#       id                                  file_name  width  height  \
# 0      1  rand_cal/images/train/set02_V001_1309.png    640     480
# 1      2  rand_cal/images/train/set00_V004_1946.png    640     480
# 2      3   rand_cal/images/train/set04_V010_995.png    640     480
# 3      4  rand_cal/images/train/set00_V006_1897.png    640     480
# 4      5  rand_cal/images/train/set05_V008_1082.png    640     480
# ..   ...                                        ...    ...     ...
# 196  197   rand_cal/images/train/set06_V000_936.png    640     480
# 197  198  rand_cal/images/train/set04_V006_1005.png    640     480
# 198  199  rand_cal/images/train/set00_V002_1266.png    640     480
# 199  200   rand_cal/images/train/set03_V004_643.png    640     480
# 200  201   rand_cal/images/train/set02_V009_153.png    640     480
#
#                   date_captured  license coco_url flickr_url
# 0    2021-04-18 13:30:31.472309        1
# 1    2021-04-18 13:30:31.472309        1
# 2    2021-04-18 13:30:31.472309        1
# 3    2021-04-18 13:30:31.472309        1
# 4    2021-04-18 13:30:31.472309        1
# ..                          ...      ...      ...        ...
# 196  2021-04-18 13:30:31.472309        1
# 197  2021-04-18 13:30:31.472309        1
# 198  2021-04-18 13:30:31.472309        1
# 199  2021-04-18 13:30:31.472309        1
# 200  2021-04-18 13:30:31.472309        1
#
# [201 rows x 8 columns]

# %%
cl_ann_df = add_area(cl_ann_df)

# %%
selected_img_df = copy.deepcopy(cl_img_df)
selected_ann_df = copy.deepcopy(cl_ann_df)
aug_img_df.shape[0] + selected_img_df.shape[0]
# Out:
# 4408

# %%
print(f'add #{selected_img_df.shape[0]} images to #{aug_img_df.shape[0]} train set')

aug_img_df, selected_ann_df = uodate_id_in_image_ann(selected_img_df, aug_img_df, selected_ann_df)

print(f'train img df after aug shape: {aug_img_df.shape[0]}')
# Out:
# add #201 images to #4207 train set
# train img df after aug shape: 4408

# %%
aug_img_df.shape[0]
# Out:
# 4408

# %%
selected_ann_df.shape[0] + ann_df_c.shape[0]
# Out:
# 51613

# %%
print(f'add #{selected_ann_df.shape[0]} annotations to #{ann_df_c.shape[0]} train set')

ann_df_c = concat_ann_df(ann_df_c, selected_ann_df)

for idx, row in ann_df_c.iterrows():
    assert idx + 1 == row['id']

print(f'train annotations #{ann_df_c.shape[0]} for train set after augmentation')
# Out:
# add #209 annotations to #51404 train set
# train annotations #51613 for train set after augmentation

# %%
ann_df_c["iscrowd"].replace({1: True, 0:False}, inplace=True)
ann_df_c['ignore'] = ann_df_c['ignore'].fillna(0)
# ann_df_c = ann_df_c.drop(['hbox', 'vbox'], axis = 1)
ann_df_c
# Out:
#           id  image_id  category_id  iscrowd                         bbox  \
# 0          1         1            1     True  [1034.0, 366.0, 31.0, 75.0]
# 1          2         1            1     True  [1911.0, 359.0, 10.0, 54.0]
# 2          3         1            1     True    [1137.0, 307.0, 8.0, 9.0]
# 3          4         2            1    False  [602.0, 413.0, 60.0, 146.0]
# 4          5         2            1    False  [281.0, 381.0, 89.0, 216.0]
# ...      ...       ...          ...      ...                          ...
# 51608  51609      4402            1    False           [544, 190, 22, 53]
# 51609  51610      4402            1    False           [493, 195, 22, 42]
# 51610  51611      4403            1    False           [512, 171, 28, 72]
# 51611  51612      4403            1    False           [542, 170, 95, 72]
# 51612  51613      4406            1    False           [523, 164, 13, 35]
#
#       width height   area  ignore
# 0      2048   1024   2325     0.0
# 1      2048   1024    540     0.0
# 2      2048   1024     72     0.0
# 3      2048   1024   8760     0.0
# 4      2048   1024  19224     0.0
# ...     ...    ...    ...     ...
# 51608   640    480   1166     0.0
# 51609   640    480    924     0.0
# 51610   640    480   2016     0.0
# 51611   640    480   6840     0.0
# 51612   640    480    455     0.0
#
# [51613 rows x 9 columns]

# %%
ann_df_c[ann_df_c.category_id != 1]
# Out:
# Empty DataFrame
# Columns: [id, image_id, category_id, iscrowd, bbox, width, height, area, ignore]
# Index: []

# %%
ann_df_c["iscrowd"].replace({1: True, 0:False}, inplace=True)
# ann_df_c['ignore'] = ann_df_c['ignore'].fillna(0)
ann_df_c
# Out:
#           id  image_id  category_id  iscrowd                         bbox  \
# 0          1         1            1     True  [1034.0, 366.0, 31.0, 75.0]
# 1          2         1            1     True  [1911.0, 359.0, 10.0, 54.0]
# 2          3         1            1     True    [1137.0, 307.0, 8.0, 9.0]
# 3          4         2            1    False  [602.0, 413.0, 60.0, 146.0]
# 4          5         2            1    False  [281.0, 381.0, 89.0, 216.0]
# ...      ...       ...          ...      ...                          ...
# 51608  51609      4402            1    False           [544, 190, 22, 53]
# 51609  51610      4402            1    False           [493, 195, 22, 42]
# 51610  51611      4403            1    False           [512, 171, 28, 72]
# 51611  51612      4403            1    False           [542, 170, 95, 72]
# 51612  51613      4406            1    False           [523, 164, 13, 35]
#
#       width height   area  ignore
# 0      2048   1024   2325     0.0
# 1      2048   1024    540     0.0
# 2      2048   1024     72     0.0
# 3      2048   1024   8760     0.0
# 4      2048   1024  19224     0.0
# ...     ...    ...    ...     ...
# 51608   640    480   1166     0.0
# 51609   640    480    924     0.0
# 51610   640    480   2016     0.0
# 51611   640    480   6840     0.0
# 51612   640    480    455     0.0
#
# [51613 rows x 9 columns]

# %%
aug_img_df
# Out:
#         id  \
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# ...    ...
# 4403  4404
# 4404  4405
# 4405  4406
# 4406  4407
# 4407  4408
#
#                                                                                                 file_name  \
# 0     CityPersons/leftImg8bit_trainvaltest//leftImg8bit/train/weimar/weimar_000117_000019_leftImg8bit.png
# 1     CityPersons/leftImg8bit_trainvaltest//leftImg8bit/train/weimar/weimar_000080_000019_leftImg8bit.png
# 2     CityPersons/leftImg8bit_trainvaltest//leftImg8bit/train/weimar/weimar_000128_000019_leftImg8bit.png
# 3     CityPersons/leftImg8bit_trainvaltest//leftImg8bit/train/weimar/weimar_000103_000019_leftImg8bit.png
# 4     CityPersons/leftImg8bit_trainvaltest//leftImg8bit/train/weimar/weimar_000063_000019_leftImg8bit.png
# ...                                                                                                   ...
# 4403                                                             rand_cal/images/train/set06_V000_936.png
# 4404                                                            rand_cal/images/train/set04_V006_1005.png
# 4405                                                            rand_cal/images/train/set00_V002_1266.png
# 4406                                                             rand_cal/images/train/set03_V004_643.png
# 4407                                                             rand_cal/images/train/set02_V009_153.png
#
#       width  height               date_captured  license coco_url flickr_url
# 0      2048    1024  2019-07-25 11:20:43.195846      1.0
# 1      2048    1024  2019-07-25 11:20:43.195846      1.0
# 2      2048    1024  2019-07-25 11:20:43.195846      1.0
# 3      2048    1024  2019-07-25 11:20:43.195846      1.0
# 4      2048    1024  2019-07-25 11:20:43.195846      1.0
# ...     ...     ...                         ...      ...      ...        ...
# 4403    640     480  2021-04-18 13:30:31.472309      1.0
# 4404    640     480  2021-04-18 13:30:31.472309      1.0
# 4405    640     480  2021-04-18 13:30:31.472309      1.0
# 4406    640     480  2021-04-18 13:30:31.472309      1.0
# 4407    640     480  2021-04-18 13:30:31.472309      1.0
#
# [4408 rows x 8 columns]

# %%
ann_df_c
# Out:
#           id  image_id  category_id  iscrowd                         bbox  \
# 0          1         1            1     True  [1034.0, 366.0, 31.0, 75.0]
# 1          2         1            1     True  [1911.0, 359.0, 10.0, 54.0]
# 2          3         1            1     True    [1137.0, 307.0, 8.0, 9.0]
# 3          4         2            1    False  [602.0, 413.0, 60.0, 146.0]
# 4          5         2            1    False  [281.0, 381.0, 89.0, 216.0]
# ...      ...       ...          ...      ...                          ...
# 51608  51609      4402            1    False           [544, 190, 22, 53]
# 51609  51610      4402            1    False           [493, 195, 22, 42]
# 51610  51611      4403            1    False           [512, 171, 28, 72]
# 51611  51612      4403            1    False           [542, 170, 95, 72]
# 51612  51613      4406            1    False           [523, 164, 13, 35]
#
#       width height   area  ignore
# 0      2048   1024   2325     0.0
# 1      2048   1024    540     0.0
# 2      2048   1024     72     0.0
# 3      2048   1024   8760     0.0
# 4      2048   1024  19224     0.0
# ...     ...    ...    ...     ...
# 51608   640    480   1166     0.0
# 51609   640    480    924     0.0
# 51610   640    480   2016     0.0
# 51611   640    480   6840     0.0
# 51612   640    480    455     0.0
#
# [51613 rows x 9 columns]

# %%
print(f"CityPersons: #{aug_img_df[aug_img_df['file_name'].str.contains('CityPersons')].shape[0]}")
# selected_caltech
print(f"selected_caltech: #{aug_img_df[aug_img_df['file_name'].str.contains('rand_cal')].shape[0]}")
# WiderPerson
print(f"WiderPerson: #{aug_img_df[aug_img_df['file_name'].str.contains('WiderPerson')].shape[0]}")
# wheelchair
print(f"wheelchair: #{aug_img_df[aug_img_df['file_name'].str.contains('selected_oi')].shape[0]}")
# CrowdHuman
print(f"CrowdHuman: #{aug_img_df[aug_img_df['file_name'].str.contains('CrowdHuman')].shape[0]}")
# EuroCity
print(f"EuroCity: #{aug_img_df[aug_img_df['file_name'].str.contains('EuroCity')].shape[0]}")
# Out:
# CityPersons: #2529
# selected_caltech: #201
# WiderPerson: #351
# wheelchair: #20
# CrowdHuman: #436
# EuroCity: #871

# %% [markdown]
# ### Save to Json

# %%
aug_data_train = dict()
aug_data_train['info'] = cp_data['info']
aug_data_train['categories'] = cp_data['categories']

aug_data_train['images'] = aug_img_df.to_dict('records')
aug_data_train['annotations'] = ann_df_c.to_dict('records')

# %%
with open('/home/test_pc/mmlab/mmdetection/datasets/random_train.json', 'w') as fp:
    json.dump(aug_data_train, fp)

# %%
cp_val = '/home/test_pc/mmlab/mmdetection/datasets/random_train.json'
f = open(cp_val)
cp_val_data = json.load(f)
# cp_val_licenses = cp_val_data['licenses']
cp_val_cat = cp_val_data['categories']
cp_val_images = cp_val_data['images']
cp_val_annotations = cp_val_data['annotations']
cp_val_img_df = pd.DataFrame(cp_val_images)
cp_val_ann_df = pd.DataFrame(cp_val_annotations)

print(f"CityPersons: #{cp_val_img_df[cp_val_img_df['file_name'].str.contains('CityPersons')].shape[0]}")
# selected_caltech
print(f"selected_caltech: #{cp_val_img_df[cp_val_img_df['file_name'].str.contains('rand_cal')].shape[0]}")
# WiderPerson
print(f"WiderPerson: #{cp_val_img_df[cp_val_img_df['file_name'].str.contains('WiderPerson')].shape[0]}")
# wheelchair
print(f"wheelchair: #{cp_val_img_df[cp_val_img_df['file_name'].str.contains('selected_oi')].shape[0]}")
# CrowdHuman
print(f"CrowdHuman: #{cp_val_img_df[cp_val_img_df['file_name'].str.contains('CrowdHuman')].shape[0]}")
# EuroCity
print(f"EuroCity: #{cp_val_img_df[cp_val_img_df['file_name'].str.contains('EuroCity')].shape[0]}")
# Out:
# CityPersons: #2529
# selected_caltech: #201
# WiderPerson: #351
# wheelchair: #20
# CrowdHuman: #436
# EuroCity: #871

# %% [markdown]
# ## Validation

# %%
cp_file = '/home/test_pc/mmlab/mmdetection/datasets/cityperson_val.json'
f = open(cp_file)
cp_data = json.load(f)
# cp_licenses = cp_data['licenses']
cp_categories = cp_data['categories']
cp_images = cp_data['images']
cp_annotations = cp_data['annotations']
cp_img_df = pd.DataFrame(cp_images)
cp_ann_df = pd.DataFrame(cp_annotations)

# %%
# for idx, row in cp_img_df.iterrows():
#     cp_img_df.at[cp_img_df.index[idx], 'file_name'] = 'CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/' + cp_img_df.at[cp_img_df.index[idx], 'file_name']
cp_img_df
# Out:
#       id  \
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5
# ..   ...
# 420  421
# 421  422
# 422  423
# 423  424
# 424  425
#
#                                                                                                       file_name  \
# 0    CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/frankfurt_000000_000294_leftImg8bit.png
# 1    CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/frankfurt_000000_000576_leftImg8bit.png
# 2    CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/frankfurt_000000_001016_leftImg8bit.png
# 3    CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/frankfurt_000000_001236_leftImg8bit.png
# 4    CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/frankfurt_000000_001751_leftImg8bit.png
# ..                                                                                                          ...
# 420    CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/munster_000168_000019_leftImg8bit.png
# 421    CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/munster_000169_000019_leftImg8bit.png
# 422    CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/munster_000170_000019_leftImg8bit.png
# 423    CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/munster_000172_000019_leftImg8bit.png
# 424    CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/munster_000173_000019_leftImg8bit.png
#
#      height  width
# 0      1024   2048
# 1      1024   2048
# 2      1024   2048
# 3      1024   2048
# 4      1024   2048
# ..      ...    ...
# 420    1024   2048
# 421    1024   2048
# 422    1024   2048
# 423    1024   2048
# 424    1024   2048
#
# [425 rows x 4 columns]

# %%
# cp_ann_df['height'] = ""
# cp_ann_df['width'] = ""
# for idx, row in cp_img_df.iterrows():            
#     cp_ann_df.loc[cp_ann_df['image_id'] == idx + 1, 'height'] = cp_img_df.at[idx, 'height']
#     cp_ann_df.loc[cp_ann_df['image_id'] == idx + 1, 'width'] = cp_img_df.at[idx, 'width']

# %%
# cp_ann_df = cp_ann_df.drop(['vis_bbox', 'vis_ratio'], axis = 1)
# cp_ann_df = add_area(cp_ann_df)
cp_ann_df
# Out:
#         id  image_id  category_id  iscrowd  ignore                 bbox  \
# 0        1         1            1        0       1  [1839, 382, 31, 71]
# 1        2         1            1        0       0   [947, 406, 17, 40]
# 2        3         1            1        0       1   [990, 374, 14, 17]
# 3        4         1            1        0       1   [1914, 73, 88, 90]
# 4        5         1            1        0       1  [1834, 101, 65, 58]
# ...    ...       ...          ...      ...     ...                  ...
# 4726  4727       423            1        0       1  [1095, 419, 14, 22]
# 4727  4728       424            1        0       1   [877, 435, 28, 17]
# 4728  4729       424            1        0       1  [1370, 391, 26, 18]
# 4729  4730       424            1        0       1  [1468, 338, 11, 13]
# 4730  4731       424            1        0       1   [925, 434, 27, 18]
#
#       height  width  area
# 0       1024   2048  2201
# 1       1024   2048   680
# 2       1024   2048   238
# 3       1024   2048  7920
# 4       1024   2048  3770
# ...      ...    ...   ...
# 4726    1024   2048   308
# 4727    1024   2048   476
# 4728    1024   2048   468
# 4729    1024   2048   143
# 4730    1024   2048   486
#
# [4731 rows x 9 columns]

# %%
aug_img_df = copy.deepcopy(cp_img_df)
ann_df_c = copy.deepcopy(cp_ann_df)

# %%
# aug_data_train['info'] = cp_info
# aug_data_train['categories'] = cp_cat
# aug_data_train['images'] = aug_img_df.to_dict('records')
# aug_data_train['annotations'] = ann_df_c.to_dict('records')
# with open('/home/test_pc/mmlab/mmdetection/datasets/cityperson_val.json', 'w') as fp:
#     json.dump(aug_data_train, fp)

# %% [markdown]
# ### ECP

# %%
index_id_list = find_index_of_images(ecp_img_df, image_name_list=val_img_ecp)

selected_img_df = create_img_df(ecp_img_df, index_id_list)

selected_ann_df = create_ann_df(ecp_ann_df, index_id_list)
selected_ann_df = add_area(selected_ann_df)
selected_ann_df
# Out:
#             id  image_id  category_id  iscrowd                         bbox  \
# 173911  173912     21301            1    False  [1183.0, 377.0, 26.0, 70.0]
# 173912  173913     21301            1    False   [752.0, 438.0, 15.0, 39.0]
# 173913  173914     21301            1     True   [626.0, 448.0, 31.0, 49.0]
# 33957    33958      5368            1    False    [51.0, 373.0, 16.0, 60.0]
# 33958    33959      5368            1    False   [353.0, 381.0, 13.0, 29.0]
# ...        ...       ...          ...      ...                          ...
# 10277    10278      1427            1     True   [1135.0, 554.0, 8.0, 25.0]
# 91217    91218     11302            1    False  [1203.0, 443.0, 27.0, 62.0]
# 91218    91219     11302            1    False  [1548.0, 435.0, 18.0, 67.0]
# 91219    91220     11302            1    False  [1562.0, 439.0, 29.0, 66.0]
# 91220    91221     11302            1     True  [1490.0, 437.0, 29.0, 57.0]
#
#         width  height  area
# 173911   1920    1024  1820
# 173912   1920    1024   585
# 173913   1920    1024  1519
# 33957    1920    1024   960
# 33958    1920    1024   377
# ...       ...     ...   ...
# 10277    1920    1024   200
# 91217    1920    1024  1674
# 91218    1920    1024  1206
# 91219    1920    1024  1914
# 91220    1920    1024  1653
#
# [1523 rows x 8 columns]

# %%
selected_img_df
# Out:
#           id                                                 file_name  width  \
# 21300  21301    EuroCity/ECP/day/img/train/toulouse/toulouse_00536.png   1920
# 5367    5368  EuroCity/ECP/day/img/train/stuttgart/stuttgart_00329.png   1920
# 9111    9112            EuroCity/ECP/day/img/train/roma/roma_00435.png   1920
# 3649    3650    EuroCity/ECP/day/img/train/budapest/budapest_00705.png   1920
# 9441    9442            EuroCity/ECP/day/img/train/roma/roma_00140.png   1920
# ...      ...                                                       ...    ...
# 13980  13981      EuroCity/ECP/day/img/train/hamburg/hamburg_00097.png   1920
# 10855  10856        EuroCity/ECP/day/img/train/milano/milano_00155.png   1920
# 12956  12957  EuroCity/ECP/day/img/train/ljubljana/ljubljana_00020.png   1920
# 1426    1427        EuroCity/ECP/day/img/train/torino/torino_00419.png   1920
# 11301  11302      EuroCity/ECP/day/img/train/zuerich/zuerich_00205.png   1920
#
#        height               date_captured  license coco_url flickr_url
# 21300    1024  2019-11-03 07:44:18.143034        1
# 5367     1024  2019-11-03 07:44:18.143034        1
# 9111     1024  2019-11-03 07:44:18.143034        1
# 3649     1024  2019-11-03 07:44:18.143034        1
# 9441     1024  2019-11-03 07:44:18.143034        1
# ...       ...                         ...      ...      ...        ...
# 13980    1024  2019-11-03 07:44:18.143034        1
# 10855    1024  2019-11-03 07:44:18.143034        1
# 12956    1024  2019-11-03 07:44:18.143034        1
# 1426     1024  2019-11-03 07:44:18.143034        1
# 11301    1024  2019-11-03 07:44:18.143034        1
#
# [168 rows x 8 columns]

# %%
print(f'add #{selected_img_df.shape[0]} images to #{aug_img_df.shape[0]} train set')
aug_img_df, selected_ann_df = uodate_id_in_image_ann(selected_img_df, aug_img_df, selected_ann_df)
print(f'train img df after aug shape: {aug_img_df.shape[0]}')
# Out:
# add #168 images to #425 train set
# train img df after aug shape: 593

# %%
print(f'add #{selected_ann_df.shape[0]} annotations to #{ann_df_c.shape[0]} train set')
ann_df_c = concat_ann_df(ann_df_c, selected_ann_df)
for idx, row in ann_df_c.iterrows():
    assert idx + 1 == row['id']

print(f'train annotations #{ann_df_c.shape[0]} for train set after augmentation')
# Out:
# add #1523 annotations to #4731 train set
# train annotations #6254 for train set after augmentation

# %% [markdown]
# ### CH

# %%
index_id_list = find_index_of_images(ch_img_df, image_name_list=val_img_ch)

selected_img_df = create_img_df(ch_img_df, index_id_list)
selected_ann_df = create_ann_df(ch_ann_df, index_id_list)

selected_ann_df = add_area(selected_ann_df)

print(f'add #{selected_img_df.shape[0]} images to #{aug_img_df.shape[0]} val set')

aug_img_df, selected_ann_df = uodate_id_in_image_ann(selected_img_df, aug_img_df, selected_ann_df, dt='ch')

print(f'train img df after aug shape: {aug_img_df.shape[0]}')

print(f'add #{selected_ann_df.shape[0]} annotations to #{ann_df_c.shape[0]} val set')
ann_df_c = concat_ann_df(ann_df_c, selected_ann_df)
for idx, row in ann_df_c.iterrows():
    assert idx + 1 == row['id']
print(f'val annotations #{ann_df_c.shape[0]} for val set after augmentation')
# Out:
# add #94 images to #593 val set
# train img df after aug shape: 687
# add #2412 annotations to #6254 val set
# val annotations #8666 for val set after augmentation

# %%
ann_df_c = ann_df_c.drop(['hbox', 'vbox'], axis = 1)
ann_df_c
# Out:
#         id  image_id  category_id  iscrowd  ignore                  bbox  \
# 0        1         1            1        0     1.0   [1839, 382, 31, 71]
# 1        2         1            1        0     0.0    [947, 406, 17, 40]
# 2        3         1            1        0     1.0    [990, 374, 14, 17]
# 3        4         1            1        0     1.0    [1914, 73, 88, 90]
# 4        5         1            1        0     1.0   [1834, 101, 65, 58]
# ...    ...       ...          ...      ...     ...                   ...
# 8661  8662       648            1        0     0.0   [333, 375, 86, 171]
# 8662  8663       648            1        0     0.0    [304, 373, 53, 96]
# 8663  8664       648            1        0     0.0   [72, 439, 165, 259]
# 8664  8665       648            1        0     0.0  [105, 396, 134, 241]
# 8665  8666       648            1        0     0.0   [310, 377, 64, 136]
#
#      height width   area
# 0      1024  2048   2201
# 1      1024  2048    680
# 2      1024  2048    238
# 3      1024  2048   7920
# 4      1024  2048   3770
# ...     ...   ...    ...
# 8661    870   580  14706
# 8662    870   580   5088
# 8663    870   580  42735
# 8664    870   580  32294
# 8665    870   580   8704
#
# [8666 rows x 9 columns]

# %%
aug_img_df.shape[0]
# Out:
# 687

# %% [markdown]
# ### wheelchair

# %%
wheel_file = '/home/test_pc/mmlab/mmdetection/datasets/selected_oi/val.json'

f = open(wheel_file)
wheel_data = json.load(f)
wheel_categories = wheel_data['categories']
wheel_images = wheel_data['images']
wheel_annotations = wheel_data['annotations']
wheel_img_df = pd.DataFrame(wheel_images)
wheel_ann_df = pd.DataFrame(wheel_annotations)
wheel_img_df.shape[0]
# Out:
# 11

# %%
wheel_ann_df = add_area(wheel_ann_df)
selected_img_df = copy.deepcopy(wheel_img_df)
selected_ann_df = copy.deepcopy(wheel_ann_df)


print(f'add #{selected_img_df.shape[0]} images to #{aug_img_df.shape[0]} val set')


aug_img_df, selected_ann_df = uodate_id_in_image_ann(selected_img_df, aug_img_df, selected_ann_df)
print(f'val img df after aug shape: {aug_img_df.shape[0]}')
# Out:
# add #11 images to #687 val set
# val img df after aug shape: 698

# %%
print(f'add #{selected_ann_df.shape[0]} annotations to #{ann_df_c.shape[0]} val set')
ann_df_c = concat_ann_df(ann_df_c, selected_ann_df)

for idx, row in ann_df_c.iterrows():
    assert idx + 1 == row['id']

print(f'val annotations #{ann_df_c.shape[0]} for val set after augmentation')
# Out:
# add #36 annotations to #8666 val set
# val annotations #8702 for val set after augmentation

# %% [markdown]
# ## WP

# %%
index_id_list = find_index_of_images(wp_img_df, image_name_list=val_img_wp)

# %%
selected_wp_img_df = create_img_df(wp_img_df, index_id_list)
selected_wp_ann_df = create_ann_df(wp_ann_df, index_id_list)
selected_wp_ann_df = add_area(selected_wp_ann_df)
print(selected_wp_img_df.shape[0])
selected_wp_ann_df.shape[0]
# Out:
# 75
# 2409

# %%
print(f'add #{selected_wp_img_df.shape[0]} images to #{aug_img_df.shape[0]} val set')
aug_img_df, selected_wp_ann_df = uodate_id_in_image_ann(selected_wp_img_df, aug_img_df, selected_wp_ann_df)
print(f'val img df after aug shape: {aug_img_df.shape[0]}')
# Out:
# add #75 images to #698 val set
# val img df after aug shape: 773

# %%
print(f'add #{selected_wp_ann_df.shape[0]} annotations to #{ann_df_c.shape[0]} val set')
ann_df_c = concat_ann_df(ann_df_c, selected_wp_ann_df)

for idx, row in ann_df_c.iterrows():
    assert idx + 1 == row['id']
print(f'val annotations #{ann_df_c.shape[0]} for val set after augmentation')
# Out:
# add #2409 annotations to #8702 val set
# val annotations #11111 for val set after augmentation

# %% [markdown]
# ### selected_caltech

# %%
ca_file = '/home/test_pc/mmlab/mmdetection/datasets/rand_cal/val.json'

f = open(ca_file)
cl_data = json.load(f)
cl_categories = cl_data['categories']
cl_images = cl_data['images']
cl_annotations = cl_data['annotations']
cl_img_df = pd.DataFrame(cl_images)
cl_ann_df = pd.DataFrame(cl_annotations)
print(cl_img_df.shape[0])
cl_ann_df = add_area(cl_ann_df)

print(cl_ann_df.shape[0])
# Out:
# 45
# 29

# %%
selected_img_df = copy.deepcopy(cl_img_df)
selected_ann_df = copy.deepcopy(cl_ann_df)
print(f'add #{selected_img_df.shape[0]} images to #{aug_img_df.shape[0]} val set')
aug_img_df, selected_ann_df = uodate_id_in_image_ann(selected_img_df, aug_img_df, selected_ann_df)
print(f'val img df after aug shape: {aug_img_df.shape[0]}')
# Out:
# add #45 images to #773 val set
# val img df after aug shape: 818

# %%
print(f'add #{selected_ann_df.shape[0]} annotations to #{ann_df_c.shape[0]} val set')
ann_df_c = concat_ann_df(ann_df_c, selected_ann_df)

for idx, row in ann_df_c.iterrows():
    assert idx + 1 == row['id']
print(f'val annotations #{ann_df_c.shape[0]} for val set after augmentation')
ann_df_c["iscrowd"].replace({1: True, 0:False}, inplace=True)
ann_df_c['ignore'] = ann_df_c['ignore'].fillna(0)
ann_df_c
# Out:
# add #29 annotations to #11111 val set
# val annotations #11140 for val set after augmentation
#           id  image_id  category_id  iscrowd  ignore                 bbox  \
# 0          1         1            1    False     1.0  [1839, 382, 31, 71]
# 1          2         1            1    False     0.0   [947, 406, 17, 40]
# 2          3         1            1    False     1.0   [990, 374, 14, 17]
# 3          4         1            1    False     1.0   [1914, 73, 88, 90]
# 4          5         1            1    False     1.0  [1834, 101, 65, 58]
# ...      ...       ...          ...      ...     ...                  ...
# 11135  11136       815            1    False     0.0   [489, 162, 15, 45]
# 11136  11137       815            1    False     0.0   [440, 163, 22, 47]
# 11137  11138       815            1    False     0.0   [414, 168, 11, 33]
# 11138  11139       816            1    False     0.0    [54, 151, 18, 80]
# 11139  11140       816            1    False     0.0    [26, 150, 24, 90]
#
#       height width  area
# 0       1024  2048  2201
# 1       1024  2048   680
# 2       1024  2048   238
# 3       1024  2048  7920
# 4       1024  2048  3770
# ...      ...   ...   ...
# 11135    480   640   675
# 11136    480   640  1034
# 11137    480   640   363
# 11138    480   640  1440
# 11139    480   640  2160
#
# [11140 rows x 9 columns]

# %%
aug_img_df
# Out:
#       id  \
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5
# ..   ...
# 813  814
# 814  815
# 815  816
# 816  817
# 817  818
#
#                                                                                                       file_name  \
# 0    CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/frankfurt_000000_000294_leftImg8bit.png
# 1    CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/frankfurt_000000_000576_leftImg8bit.png
# 2    CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/frankfurt_000000_001016_leftImg8bit.png
# 3    CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/frankfurt_000000_001236_leftImg8bit.png
# 4    CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/frankfurt_000000_001751_leftImg8bit.png
# ..                                                                                                          ...
# 813                                                                     rand_cal/images/val/set03_V004_1095.png
# 814                                                                     rand_cal/images/val/set00_V007_1255.png
# 815                                                                     rand_cal/images/val/set00_V006_1590.png
# 816                                                                     rand_cal/images/val/set02_V005_1664.png
# 817                                                                      rand_cal/images/val/set02_V004_758.png
#
#      height  width               date_captured  license coco_url flickr_url
# 0      1024   2048                         NaN      NaN      NaN        NaN
# 1      1024   2048                         NaN      NaN      NaN        NaN
# 2      1024   2048                         NaN      NaN      NaN        NaN
# 3      1024   2048                         NaN      NaN      NaN        NaN
# 4      1024   2048                         NaN      NaN      NaN        NaN
# ..      ...    ...                         ...      ...      ...        ...
# 813     480    640  2021-04-18 13:30:22.721543      1.0
# 814     480    640  2021-04-18 13:30:22.721543      1.0
# 815     480    640  2021-04-18 13:30:22.721543      1.0
# 816     480    640  2021-04-18 13:30:22.721543      1.0
# 817     480    640  2021-04-18 13:30:22.721543      1.0
#
# [818 rows x 8 columns]

# %%
aug_img_df['date_captured'] = ""
aug_img_df['license'] = ""
aug_img_df['coco_url'] = ""
aug_img_df['flickr_url'] = ""
aug_img_df
# Out:
#       id  \
# 0      1
# 1      2
# 2      3
# 3      4
# 4      5
# ..   ...
# 813  814
# 814  815
# 815  816
# 816  817
# 817  818
#
#                                                                                                       file_name  \
# 0    CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/frankfurt_000000_000294_leftImg8bit.png
# 1    CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/frankfurt_000000_000576_leftImg8bit.png
# 2    CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/frankfurt_000000_001016_leftImg8bit.png
# 3    CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/frankfurt_000000_001236_leftImg8bit.png
# 4    CityPersons/leftImg8bit_trainvaltest/leftImg8bit/val_all_in_folder/frankfurt_000000_001751_leftImg8bit.png
# ..                                                                                                          ...
# 813                                                                     rand_cal/images/val/set03_V004_1095.png
# 814                                                                     rand_cal/images/val/set00_V007_1255.png
# 815                                                                     rand_cal/images/val/set00_V006_1590.png
# 816                                                                     rand_cal/images/val/set02_V005_1664.png
# 817                                                                      rand_cal/images/val/set02_V004_758.png
#
#      height  width date_captured license coco_url flickr_url
# 0      1024   2048
# 1      1024   2048
# 2      1024   2048
# 3      1024   2048
# 4      1024   2048
# ..      ...    ...           ...     ...      ...        ...
# 813     480    640
# 814     480    640
# 815     480    640
# 816     480    640
# 817     480    640
#
# [818 rows x 8 columns]

# %%
ann_df_c[ann_df_c.category_id != 1]
# Out:
# Empty DataFrame
# Columns: [id, image_id, category_id, iscrowd, ignore, bbox, height, width, area]
# Index: []

# %%
ann_df_c["iscrowd"].replace({1: True, 0:False}, inplace=True)
ann_df_c['ignore'] = ann_df_c['ignore'].fillna(0)
ann_df_c
# Out:
#           id  image_id  category_id  iscrowd  ignore                 bbox  \
# 0          1         1            1    False     1.0  [1839, 382, 31, 71]
# 1          2         1            1    False     0.0   [947, 406, 17, 40]
# 2          3         1            1    False     1.0   [990, 374, 14, 17]
# 3          4         1            1    False     1.0   [1914, 73, 88, 90]
# 4          5         1            1    False     1.0  [1834, 101, 65, 58]
# ...      ...       ...          ...      ...     ...                  ...
# 11135  11136       815            1    False     0.0   [489, 162, 15, 45]
# 11136  11137       815            1    False     0.0   [440, 163, 22, 47]
# 11137  11138       815            1    False     0.0   [414, 168, 11, 33]
# 11138  11139       816            1    False     0.0    [54, 151, 18, 80]
# 11139  11140       816            1    False     0.0    [26, 150, 24, 90]
#
#       height width  area
# 0       1024  2048  2201
# 1       1024  2048   680
# 2       1024  2048   238
# 3       1024  2048  7920
# 4       1024  2048  3770
# ...      ...   ...   ...
# 11135    480   640   675
# 11136    480   640  1034
# 11137    480   640   363
# 11138    480   640  1440
# 11139    480   640  2160
#
# [11140 rows x 9 columns]

# %%
print(f"CityPersons: #{aug_img_df[aug_img_df['file_name'].str.contains('CityPersons')].shape[0]}")
# selected_caltech
print(f"selected_caltech: #{aug_img_df[aug_img_df['file_name'].str.contains('rand_cal')].shape[0]}")
# WiderPerson
print(f"WiderPerson: #{aug_img_df[aug_img_df['file_name'].str.contains('WiderPerson')].shape[0]}")
# wheelchair
print(f"wheelchair: #{aug_img_df[aug_img_df['file_name'].str.contains('selected_oi')].shape[0]}")
# CrowdHuman
print(f"CrowdHuman: #{aug_img_df[aug_img_df['file_name'].str.contains('CrowdHuman')].shape[0]}")
# EuroCity
print(f"EuroCity: #{aug_img_df[aug_img_df['file_name'].str.contains('EuroCity')].shape[0]}")
# Out:
# CityPersons: #425
# selected_caltech: #45
# WiderPerson: #75
# wheelchair: #11
# CrowdHuman: #94
# EuroCity: #168

# %% [markdown]
# ### Save json file

# %%
aug_data_train = dict()
aug_data_train['info'] = cp_info
aug_data_train['categories'] = cp_data['categories']
aug_data_train['images'] = aug_img_df.to_dict('records')
aug_data_train['annotations'] = ann_df_c.to_dict('records')
with open('/home/test_pc/mmlab/mmdetection/datasets/random_val.json', 'w') as fp:
    json.dump(aug_data_train, fp)

# %%
cp_val = '/home/test_pc/mmlab/mmdetection/datasets/random_val.json'
f = open(cp_val)
cp_val_data = json.load(f)
# cp_val_licenses = cp_val_data['licenses']
cp_val_cat = cp_val_data['categories']
cp_val_images = cp_val_data['images']
cp_val_annotations = cp_val_data['annotations']
cp_val_img_df = pd.DataFrame(cp_val_images)
cp_val_ann_df = pd.DataFrame(cp_val_annotations)

print(f"CityPersons: #{cp_val_img_df[cp_val_img_df['file_name'].str.contains('CityPersons')].shape[0]}")
# selected_caltech
print(f"selected_caltech: #{cp_val_img_df[cp_val_img_df['file_name'].str.contains('rand_cal')].shape[0]}")
# WiderPerson
print(f"WiderPerson: #{cp_val_img_df[cp_val_img_df['file_name'].str.contains('WiderPerson')].shape[0]}")
# wheelchair
print(f"wheelchair: #{cp_val_img_df[cp_val_img_df['file_name'].str.contains('selected_oi')].shape[0]}")
# CrowdHuman
print(f"CrowdHuman: #{cp_val_img_df[cp_val_img_df['file_name'].str.contains('CrowdHuman')].shape[0]}")
# EuroCity
print(f"EuroCity: #{cp_val_img_df[cp_val_img_df['file_name'].str.contains('EuroCity')].shape[0]}")
# Out:
# CityPersons: #425
# selected_caltech: #45
# WiderPerson: #75
# wheelchair: #11
# CrowdHuman: #94
# EuroCity: #168

# %% [markdown]
# # data leakage check!

# %%
random_train = '/home/test_pc/mmlab/mmdetection/datasets/random_train.json'
sem_test = '/home/test_pc/mmlab/mmdetection/datasets/aug_test.json'

# %%
f_rtr = open(random_train)
random_train_data = json.load(f_rtr)
random_train_cat = random_train_data['categories']
random_train_images = random_train_data['images']
random_train_annotations = random_train_data['annotations']
random_train_img_df = pd.DataFrame(random_train_images)
random_train_ann_df = pd.DataFrame(random_train_annotations)

# %%
f_st = open(sem_test)
sem_test_data = json.load(f_st)
sem_test_cat = sem_test_data['categories']
sem_test_images = sem_test_data['images']
sem_test_annotations = sem_test_data['annotations']
sem_test_img_df = pd.DataFrame(sem_test_images)
sem_test_ann_df = pd.DataFrame(sem_test_annotations)

# %%
random_train_cp = random_train_img_df[random_train_img_df['file_name'].str.contains('CityPersons')]
sem_test_cp = sem_test_img_df[sem_test_img_df['file_name'].str.contains('CityPersons')]

# %%
cp_tr = set([el.rsplit('/', 1)[1] for el in list(random_train_cp['file_name'])])
cp_ts = set([el.rsplit('/', 1)[1] for el in list(sem_test_cp['file_name'])])
print("set1 intersection set2 : ", cp_tr.intersection(cp_ts))
# Out:
# set1 intersection set2 :  set()

# %%
random_train_cl = random_train_img_df[random_train_img_df['file_name'].str.contains('rand_cal')]
sem_test_cl = sem_test_img_df[sem_test_img_df['file_name'].str.contains('selected_caltech')]

# %%
cl_tr = set([el.rsplit('/', 1)[1] for el in list(random_train_cl['file_name'])])
cl_ts = set([el.rsplit('/', 1)[1] for el in list(sem_test_cl['file_name'])])
print("set1 intersection set2 : ", cl_tr.intersection(cl_ts))
# Out:
# set1 intersection set2 :  set()

# %%
random_train_wp = random_train_img_df[random_train_img_df['file_name'].str.contains('WiderPerson')]
sem_test_wp = sem_test_img_df[sem_test_img_df['file_name'].str.contains('WiderPerson')]

# %%
wp_tr = set([el.rsplit('/', 1)[1] for el in list(random_train_wp['file_name'])])
wp_ts = set([el.rsplit('/', 1)[1] for el in list(sem_test_wp['file_name'])])
print("set1 intersection set2 : ", wp_tr.intersection(wp_ts))
# Out:
# set1 intersection set2 :  set()

# %%
random_train_wl = random_train_img_df[random_train_img_df['file_name'].str.contains('selected_oi')]
sem_test_wl = sem_test_img_df[sem_test_img_df['file_name'].str.contains('wheelchair')]

# %%
wl_tr = set([el.rsplit('/', 1)[1] for el in list(random_train_wl['file_name'])])
wl_ts = set([el.rsplit('/', 1)[1] for el in list(sem_test_wl['file_name'])])
print("set1 intersection set2 : ", wl_tr.intersection(wl_ts))
# Out:
# set1 intersection set2 :  set()

# %%
random_train_ch = random_train_img_df[random_train_img_df['file_name'].str.contains('CrowdHuman')]
sem_test_ch = sem_test_img_df[sem_test_img_df['file_name'].str.contains('CrowdHuman')]

# %%
ch_tr = set([el.rsplit('/', 1)[1] for el in list(random_train_ch['file_name'])])
ch_ts = set([el.rsplit('/', 1)[1] for el in list(sem_test_ch['file_name'])])
print("set1 intersection set2 : ", ch_tr.intersection(ch_ts))
# Out:
# set1 intersection set2 :  set()

# %%
random_train_ec = random_train_img_df[random_train_img_df['file_name'].str.contains('EuroCity')]
sem_test_ec = sem_test_img_df[sem_test_img_df['file_name'].str.contains('EuroCity')]

# %%
ec_tr = set([el.rsplit('/', 1)[1] for el in list(random_train_ec['file_name'])])
ec_ts = set([el.rsplit('/', 1)[1] for el in list(sem_test_ec['file_name'])])
print("set1 intersection set2 : ", ec_tr.intersection(ec_ts))
# Out:
# set1 intersection set2 :  set()
